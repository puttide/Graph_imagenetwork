# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !sudo apt-get install python-numpy gdal-bin libgdal-dev
# !pip install rasterio
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# gdal-bin is already the newest version (2.2.3+dfsg-2).
# libgdal-dev is already the newest version (2.2.3+dfsg-2).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/f0/f0/8a62d7b4fe4f6093a7b7cefdac476ea5edbf3f7e40050add93298e74629b/rasterio-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (19.1MB)
#      |████████████████████████████████| 19.1MB 268kB/s
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2020.12.5)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (20.3.0)
# Collecting click-plugins
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.19.5)
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Installing collected packages: cligj, click-plugins, affine, snuggs, rasterio
# Successfully installed affine-2.3.0 click-plugins-1.1.1 cligj-0.7.1 rasterio-1.2.2 snuggs-1.4.7

# %%
dataset_dir='/content/gdrive/My Drive/ISPRS_semantic_labeling_Vaihingen/'
train_x_path='/content/gdrive/My Drive/ISPRS_semantic_labeling_Vaihingen/top1'
train_y_path='/content/gdrive/My Drive/ISPRS_semantic_labeling_Vaihingen/gts1'
test_x_path='/content/gdrive/My Drive/ISPRS_semantic_labeling_Vaihingen/top2'
test_y_path='/content/gdrive/My Drive/ISPRS_semantic_labeling_Vaihingen/gts2'

# %%
import rasterio
def reading_image(path):
  src = rasterio.open(path)
  array = src.read()
  return array

# %%
def convert_gt_binary(building_gt):
  return np.where(building_gt>0.8,1.0,0.0)

# %%
import cv2
def resiz(building_gt):
  dim=(512,512)
  resized = cv2.resize(building_gt, dim, interpolation = cv2.INTER_AREA)
  return resized

# %%
from torch.utils.data import Dataset
from torchvision import transforms
from natsort import natsorted
import os
import numpy as np


class BRATSDataset2D(Dataset):

    def __init__(self, input_path,gt_path, transform=None,binarise=True):
        input_paths=[os.path.join(input_path,folder) for folder in os.listdir(input_path) ]
        input_paths=natsorted(input_paths)
        label_paths=[os.path.join(gt_path,folder) for folder in os.listdir(gt_path) ]
        label_paths=natsorted(label_paths)
        #input_paths=[read_input_paths(subfolder)  for subfolder in subfolders]
        #label_paths=[read_label_paths(subfolder)  for subfolder in subfolders]
        self.binarise=True
        self.datastore = []
        for inps,lbl in zip(input_paths,label_paths):
          #im_inps=np.asarray(np.load(inps)) #for x in inps])
          #labels=np.asarray([np.load(y) for y in lbl])
          #for i in range(im_inps.shape[0]):
            #slc = im_inps[...,i]
            #slc = im_inps[i,:,:,:]
            #if slc.min() == 0 and slc.max() == 0:
            #  continue
            #datum = (inps, lbl, i)
            
            datum = (inps, lbl)
            self.datastore.append(datum)

        self.transform = transform

    def __len__(self):
        return len(self.datastore)

    def __getitem__(self, idx):
      datum = self.datastore[idx]
      
      im_inps=reading_image(datum[0])###########Reading tif image with rasterio
      im_inps=np.transpose(im_inps,(1,2,0))
      im_inps=resiz(im_inps)                  ######Resizing input image
      im_inps=np.transpose(im_inps,(2,0,1))
      im_inps=im_inps/np.max(im_inps)         #######Normalizing input
      #im_inps=(im_inps-0.3605692566298038)/0.18194970820847367
      labels=reading_image(datum[1])#np.asarray(np.load(datum[1]))# for y in lbl])
      
      labels=resiz(labels[1])
      labels=convert_gt_binary(np.squeeze(labels))#######preparing gt for only buildings
      
      
      return im_inps, labels

# %%
def plot_bi1(inpt,ori_imgs,  figsize = (5, 5)):
    IMG_SIZE=512
    print()
    fig, axes = plt.subplots(1, 2, figsize = figsize)
    fig.subplots_adjust(hspace=0.4, wspace = 0.4, right =0.7)
    
    axes[0].imshow(inpt)
    axes[0].set_xlabel('inp')
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    
    axes[1].imshow(ori_imgs)#np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]))
    axes[1].set_xlabel('mask')
    axes[1].set_xticks([])
    axes[1].set_yticks([])

    
   

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

my_dataset = BRATSDataset2D(input_path=train_x_path,gt_path=train_y_path,binarise=True)
mean1=0.0
std1=0.0
for e1,e2 in my_dataset:
  #mean1+=np.mean(e1)
  #std1+=np.std(e1)
  #print(mean1/12,std1/12)
  e1=np.transpose(e1,(1,2,0))
  plot_bi1(e1,e2)
# Out:
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
print(len(my_dataset))
im=my_dataset[1][0]
print(im.shape)
im=(im-0.3605692566298038)/0.18194970820847367
print(np.mean(im),np.std(im))
print(np.max(im),print(np.min(im)))
# Out:
# 12
# (3, 512, 512)
# 0.03339281730637498 0.9078126070386475
# -1.6584018198715988
# 3.514326841555314 None
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 11.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.19.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (54.2.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.2

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.7/dist-packages (3.0.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from nibabel) (1.19.5)

# %%
import tensorflow as tf
from tensorflow import summary
import datetime,json
import string

# %load_ext tensorboard
current_time=str(datetime.datetime.now().timestamp())
train_log_dir='logs/tensorboard/train'+current_time
test_log_dir='logs/tensorboard/test'+current_time
train_summary_writer=summary.create_file_writer(train_log_dir)
test_summary_writer=summary.create_file_writer(test_log_dir)

# %%
'''
@tf.function
def my_func(step,loss):
  with train_summary_writer.as_default():
    tf.summary.scalar("loss",loss,step)
'''
# Out:
# '\n@tf.function\ndef my_func(step,loss):\n  with train_summary_writer.as_default():\n    tf.summary.scalar("loss",loss,step)\n'

# %%
import os
from scipy.ndimage import zoom  # For resizing
#subfolders=[os.path.join(folder_path_fully,folder) for folder in os.listdir(folder_path_fully) ]

#print(subfolders)

# %%
import numpy as np
import rasterio
#import nibabel as nib

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#import torch_geometric.nn as pyg_nn
#import torch_geometric.utils as pyg_utils

import time
from datetime import datetime

#import networkx as nx
import numpy as np
import torch
import torch.optim as optim
#from torchvision.datasets import MNIST
import multiprocessing

import numpy as np
import scipy as sp
from skimage.segmentation import slic, mark_boundaries
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
NP_TORCH_FLOAT_DTYPE = np.float32
NP_TORCH_LONG_DTYPE = np.int64

# %%
import torch
#import networkx as nx

# %matplotlib inline

# %%
def dice_loss(input, target):
    """ This is a normal dice loss function for binary segmentation.
    Args:
        input: output of the segmentation network
        target: ground truth label
    Returns:
        dice score
    """
    smooth = 1
    #input = F.softmax(input, dim=1)
    # input = torch.sigmoid(input) #for binary
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    union = iflat.sum() + tflat.sum()
    dice_score = (2.*intersection + smooth)/(union + smooth)
    return 1-dice_score

class BinaryDiceLoss(nn.Module):
    """Dice loss of binary class
    Args:
        smooth: A float number to smooth loss, and avoid NaN error, default: 1
        p: Denominator value: \sum{x^p} + \sum{y^p}, default: 2
        predict: A tensor of shape [N, *]
        target: A tensor of shape same with predict
        reduction: Reduction method to apply, return mean over batch if 'mean',
            return sum if 'sum', return a tensor of shape [N,] if 'none'
    Returns:
        Loss tensor according to arg reduction
    Raise:
        Exception if unexpected reduction
    """
    def __init__(self, smooth=1, p=2, reduction='mean'):
        super(BinaryDiceLoss, self).__init__()
        self.smooth = smooth
        self.p = p
        self.reduction = reduction

    def forward(self, predict, target):
        assert predict.shape[0] == target.shape[0], "predict & target batch size don't match"
        #predict=F.softmax(predict, dim=1)
        predict = predict.contiguous().view(predict.shape[0], -1)
        target = target.contiguous().view(target.shape[0], -1)

        num = torch.sum(torch.mul(predict, target), dim=1) + self.smooth
        den = torch.sum(predict.pow(self.p) + target.pow(self.p), dim=1) + self.smooth

        loss = 1 - num / den

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        elif self.reduction == 'none':
            return loss
        else:
            raise Exception('Unexpected reduction {}'.format(self.reduction))


class DiceLoss(nn.Module):
    """Dice loss, need one hot encode input
    Args:
        weight: An array of shape [num_classes,]
        ignore_index: class index to ignore
        predict: A tensor of shape [N, C, *]
        target: A tensor of same shape with predict
        other args pass to BinaryDiceLoss
    Return:
        same as BinaryDiceLoss
    """
    def __init__(self, weight=None, ignore_index=None, **kwargs):
        super(DiceLoss, self).__init__()
        self.kwargs = kwargs
        self.weight = weight
        self.ignore_index = ignore_index
        self.dice = BinaryDiceLoss(**self.kwargs)

    def forward(self, predict, target):
        assert predict.shape == target.shape, 'predict & target shape do not match'

        total_loss = 0
        for i in range(target.shape[1]):
            if i != self.ignore_index:
                dice_loss = dice(predict[:, i], target[:, i])
                if self.weight is not None:
                    assert self.weight.shape[0] == target.shape[1], \
                        'Expect weight shape [{}], get[{}]'.format(target.shape[1], self.weight.shape[0])
                    dice_loss *= self.weights[i]
                total_loss += dice_loss

        return total_loss/target.shape[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#import torch_geometric.nn as pyg_nn
#import torch_geometric.utils as pyg_utils

import time
from datetime import datetime

#import networkx as nx
import numpy as np
import torch
import torch.optim as optim
#from torchvision.datasets import MNIST
import multiprocessing

import numpy as np
import scipy as sp
from skimage.segmentation import slic, mark_boundaries
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
NP_TORCH_FLOAT_DTYPE = np.float32
NP_TORCH_LONG_DTYPE = np.int64

# %%
import torch
#import networkx as nx

# %matplotlib inline

# %%
from tensorboardX import SummaryWriter
writer = SummaryWriter(logdir='/content/runs')
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import pdb
import torch
import torch.nn as nn

from torch.nn.functional import softmax


class CNNfeaturemap(torch.nn.Module):
  def __init__(self):
        super(CNNfeaturemap, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, stride=1,padding=1)
        #self.maxpool1=nn.MaxPool2d(3, stride=2,padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=1,padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, stride=1,padding=1)
        self.conv6 = nn.Conv2d(128, 256, 3, stride=1,padding=1)
        #self.maxpool2=nn.MaxPool2d(3, stride=2,padding=1)
        self.conv7 = nn.Conv2d(256, 1024, 3, stride=1,padding=1)
        
        #self.layernorm=nn.LayerNorm([14, 14])
        #self.layernorm1=nn.LayerNorm([7, 7])
        #self.layernorm2=nn.LayerNorm([7, 7])

  def forward(self, x):
        #print(torch.max(x))
        x1 = F.leaky_relu(self.conv1(x),0.2)#F.leaky_relu(self.maxpool1(self.conv1(x)),0.2)#F.leaky_relu(self.conv1(x))
        #x1=self.layernorm(x1)
        x2 = F.leaky_relu(self.conv2(x1),0.2)
        x3 = F.leaky_relu(self.conv3(x2),0.2)
        #x4 = F.leaky_relu(self.conv1(x3))
        
        #x6 = F.leaky_relu(self.maxpool2(self.conv6(x1)),0.2)#F.relu(self.conv6(x1))
        x6 = F.leaky_relu(self.conv6(x3),0.2)#F.relu(self.conv6(x1))
        #x6=self.layernorm1(x6)
        x7 = F.leaky_relu(self.conv7(x6),0.2)
        #x7=self.layernorm2(x7)

        #print('torch_max',torch.max(x7))
               
        return x7




class Encoder(torch.nn.Module):                        ######### aim is to create feature vector for GNN
  def __init__(self):                                  ###### Basic AE advanced VAE
        super(Encoder, self).__init__()                ###### Adaptive average pooling  and then flattened vector should be the output
        self.conv1 = nn.Conv2d(1024, 512, 3, stride=1,padding=1)
        self.conv2 = nn.Conv2d(512, 128, 3, stride=1,padding=1)
        self.conv5 = nn.Conv2d(128, 6, 3, stride=1,padding=1)
        self.conv6 = nn.Conv2d(6, 6, 3, stride=1,padding=1)
        self.conv7 = nn.Conv2d(6, 6, 1, stride=1)
  def reparameterize(self, mu, log_var):
        ##std = logvar.mul(0.5).exp_()
        std=torch.exp(0.5*log_var)
        esp = torch.randn(*mu.size()).cuda()
        z = mu + std * esp
        return z
  def bottleneck(self, h):
        mu, logvar = self.fc1(h), self.fc2(h)
        z = self.reparameterize(mu, logvar)
        return z, mu, logvar
        
  def representation(self, x):
        return self.bottleneck(self.encoder(x))[0]
        

  def forward(self, x):
        x1 = F.leaky_relu(self.conv1(x),0.2)
        #print(x1.size())
        x2 = F.leaky_relu(self.conv2(x1),0.2)
        
        x5 = F.leaky_relu(self.conv5(x2),0.2)
        #print(torch.max(x5))
        x6=torch.nn.AdaptiveAvgPool2d(32)(x5)
        
        feat=torch.nn.Flatten()(x6)
        mu = torch.nn.Flatten()(self.conv6(x6))
        logvar = torch.nn.Flatten()(self.conv7(x6))
        z=self.reparameterize(mu, logvar)

        return z,feat,mu,logvar

class Decoder(torch.nn.Module):            ######### aim is to create Adjacency matrix and Feature vector
  def __init__(self ):                     ###### inner product is adjacency matrix
        super(Decoder, self).__init__()   

  def gamma(A):
    gam=1+49/(torch.sum(A)+10e-7)    
    gam=gam.pow(0.5)    
    A1=A+gam*torch.diag(A)        
    return gam,A1
  
  def forward(self, x):
        A=x@x.t()
        gam=1+49/(torch.sum(A)+10e-7)    #################
        gam=gam.pow(0.5)                  ###########         Creating adaptive factor gamma
        A1=A+gam*torch.diag(A)           #########adding adaptive enhancement to adjacency matrix

        return gam,A1,x
#p=torch.zeros((1,1024,7,7))
#a,b,c,d=Encoder()(p)
#print(a.size())
#a,b,c,d=Encoder()(p)
#print(ad.size(),xt.size())



class GINConv(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
        self.linear = torch.nn.Linear(6, 6)
        self.linear1=torch.nn.Linear(6, 6)

    def forward(self, A, X):
        """
        Params
        ------
        A [batch x nodes x nodes]: adjacency matrix
        X [batch x nodes x features]: node features matrix
        
        Returns
        -------
        X' [batch x nodes x features]: updated node features matrix
        """
        X = self.linear(X + A @ X )#+ A**2 @ X)
        X1 = F.leaky_relu(X,0.2)
        X2=self.linear1(X1 + A @ X1)
        gam=1+49/(torch.sum(A)+10e-7)    #################
        gam=gam.pow(0.5) 
        z_sum_opt=gam*X1+X2
        
        return z_sum_opt
'''
def dice_loss(pred,target):
    numerator = 2 * torch.sum(pred * target)
    denominator = torch.sum(pred + target)
    return 1 - (numerator + 1) / (denominator + 1)#1 - (numerator + 1) / (denominator + 1)
'''
def kld_loss(mu,logvar):
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return KLD
def kdl_loss(gamm,A):
  kdl1=-gamm/32*32
  #kdl=kdl1*torch.sum(torch.log(torch.clamp(A, min=0, max=1)+10e-7))
  kdl=kdl1*torch.sum(torch.log(A/torch.max(A))+10e-7)
  return kdl
class SCG(torch.nn.Module):
    def __init__(self,cnnfeaturemap,encoder,decoder,gin):
        super(SCG, self).__init__()
        self.cnnfeaturemap=cnnfeaturemap#CNNfeaturemap()
        self.encoder=encoder#Encoder()
        self.decoder=decoder#Decoder()
        self.gin=gin#GINConv()
        self.conv1=nn.Conv2d(6, 6, 3, stride=1,padding=1)
        self.upsample1=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample2=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample3=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample4=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample5=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample6=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample7=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.upsample8=torch.nn.Upsample(scale_factor=2, mode='nearest')
        self.conv2=nn.Conv2d(6, 6, 3, stride=1,padding=1)
        #self.layernorm=nn.LayerNorm([28, 28])
        self.conv3=nn.Conv2d(6, 36, 3, stride=1,padding=1)
        self.conv4=nn.Conv2d(36, 128, 3, stride=1,padding=1)
        self.conv5=nn.Conv2d(128, 256, 3, stride=1,padding=1)
        self.conv6=nn.Conv2d(256, 512, 3, stride=1,padding=1)
        self.conv7=nn.Conv2d(512, 1024, 3, stride=1,padding=1)
        self.conv8=nn.Conv2d(1024, 512, 3, stride=1,padding=1)
        self.conv9=nn.Conv2d(512, 256, 3, stride=1,padding=1)
        self.conv10=nn.Conv2d(256, 128, 3, stride=1,padding=1)
        self.conv11=nn.Conv2d(128, 36, 3, stride=1,padding=1)
        self.conv12=nn.Conv2d(36, 6, 3, stride=1,padding=1)
        self.conv13=nn.Conv2d(6, 1, 3, stride=1,padding=1)
        self.layernorm1=nn.LayerNorm([512, 512])

        

    def forward(self, x):
        cnf=self.cnnfeaturemap(x)
        #print('cnf',cnf.size())
        z,feat,mu,logvar=self.encoder(cnf)
        #enc1=enc.squeeze()
        #print(z.size())
        #z=torch.reshape(z,(32*32,6))
        #gam,adj,featurematrix=self.decoder(z)
        #print(adj.size(),featurematrix.size())
        #fmatrix=self.gin(adj,featurematrix)
        
        
        fmatrix=torch.reshape(z,(1,6,32,32))
        fmatrix=self.conv1(fmatrix)
        fmatrix1=F.leaky_relu(fmatrix,0.2)
        #z1=mu*(1-logvar)                                                ########### residual term as per paper
        #z1=z1*gam                                                       ########## adaptive enhancement gam is added to residual z1
        #fmatrix1=nn.Flatten()(fmatrix1)
        #zf=z1+fmatrix1
        #zf=fmatrix1
        zf=torch.reshape(fmatrix1,(1,6,32,32))
        zf=self.upsample1(zf)
        fmatrix2=self.conv2(zf)
        fmatrix2=F.leaky_relu(fmatrix2,0.2)
        
        #fmatrix2=self.layernorm(fmatrix2)
        fmatrix3=self.conv3(fmatrix2)
        fmatrix3=F.leaky_relu(fmatrix3,0.2)
        
        fmatrix4=self.conv4(fmatrix3)
        fmatrix4=F.leaky_relu(fmatrix4,0.2)
        fmatrix5=self.conv5(fmatrix4)
        fmatrix5=F.leaky_relu(fmatrix5,0.2)
        fmatrix6=self.conv6(fmatrix5)
        fmatrix6=F.leaky_relu(fmatrix6,0.2)
        fmatrix7=self.conv7(fmatrix6)
        fmatrix7=F.leaky_relu(fmatrix7,0.2)
        fmatrix8=self.conv8(fmatrix7)
        fmatrix8=F.leaky_relu(fmatrix8,0.2)
        fmatrix9=self.conv9(fmatrix8)
        
        fmatrix9=F.leaky_relu(fmatrix9,0.2)
        fmatrix9=self.upsample2(fmatrix9)
        fmatrix10=self.conv10(fmatrix9)
        
        fmatrix10=F.leaky_relu(fmatrix10,0.2)
        fmatrix10=self.upsample3(fmatrix10)
        #fmatrix10=self.conv10(fmatrix10)
        fmatrix11=self.conv11(fmatrix10)
        fmatrix11=F.leaky_relu(fmatrix11,0.2)
        fmatrix11=self.upsample4(fmatrix11)
        fmatrix12=self.conv12(fmatrix11)
        fmatrix12=F.leaky_relu(fmatrix12,0.2)
        #fmatrix12=self.upsample5(fmatrix12)
        fmatrix13=self.conv13(fmatrix12)
        #fmatrix13=F.leaky_relu(fmatrix13,0.2)
        fmatrix14=self.layernorm1(fmatrix13)
        fmatrix14=torch.reshape(fmatrix14,(1,1,512,512))
        
        #fmatrix2=nn.LogSoftmax(dim=1)(fmatrix2)
        
        fmatrix14=torch.sigmoid(fmatrix14)
        #fmatrix2=nn.Softmax(dim=1)(fmatrix2)

        return fmatrix14,mu,logvar,cnf,z,feat#fmatrix14,mu,logvar,gam,adj,x,cnf,z,feat

# %%
class Dice(nn.Module):
    """
    Class used to get dice_loss and dice_score
    """

    def __init__(self, smooth=1):
        super(Dice, self).__init__()
        self.smooth = smooth

    def forward(self, y_pred, y_true):
        y_pred_f = torch.flatten(y_pred)
        y_true_f = torch.flatten(y_true)
        intersection = torch.sum(y_true_f * y_pred_f)
        union = torch.sum(y_true_f + y_pred_f)
        dice_score = (2. * intersection + self.smooth) / (union + self.smooth)
        dice_loss = 1 - dice_score
        return dice_loss
diceloss=Dice()

# %%
from torch.utils.data import TensorDataset, DataLoader
 
cnnfeaturemap=CNNfeaturemap()
encoder=Encoder()
decoder=Decoder()
gin=GINConv()

model = SCG(cnnfeaturemap,encoder,decoder,gin)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" )



from torch.utils.data import TensorDataset, DataLoader
 


#use_cuda = torch.cuda.is_available()
#device = torch.device("cuda:0" )

my_dataset = BRATSDataset2D(input_path=train_x_path,gt_path=train_y_path,binarise=True)
train_loader = DataLoader(my_dataset,batch_size=1, shuffle=True)
test_dataset = BRATSDataset2D(input_path=test_x_path,gt_path=test_y_path,binarise=True)
test_loader = DataLoader(test_dataset,batch_size=1,shuffle=True)
writer = SummaryWriter()

model.cuda()

optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
#lr = base_lr * (1 −iter / maxiter ) ^ 0.9
#optimizer=torch.optim.Adam(model.parameters(),lr=0.00001,eps=1e-08, weight_decay=1e-4)
#scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(train_loader), epochs=10)
batch_size=4
trainingloss=[]
testloss=[]
iters=[]

train_input=[]
test_input=[]
train_pred=[]
test_pred=[]
train_gt=[]
test_gt=[]
train_iter_epoch=[]
test_iter_epoch=[]
test_losses=[]
train_losses = []
valid_losses = []
#loss_fn=BinaryDiceLoss()
#testloss=BinaryDiceLoss()
#model.cuda()

#optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
train_losses = []
valid_losses = []
num_epochs=5000
for epoch in range(1, num_epochs + 1):
    # keep-track-of-training-and-validation-loss
    train_loss = 0.0
    valid_loss = 0.0
    #scheduler.step()
    # training-the-model
    model.train()
    for data, target in train_loader:
        # move-tensors-to-GPU 
        data = data.to(device).float()
        target = target.to(device).float()
        
        # clear-the-gradients-of-all-optimized-variables
        optimizer.zero_grad()
        # forward-pass: compute-predicted-outputs-by-passing-inputs-to-the-model
        #print(data.shape)
        #data=data.permute(0,3,1,2)
        outputtr,mu1,logvar1,cnf1,z1,feat1 = model(data)
        # calculate-the-batch-loss
        loss=diceloss(outputtr,target)+0.0001*kld_loss(mu1,logvar1)#+kdl_loss(gam1,adj1)
        # backward-pass: compute-gradient-of-the-loss-wrt-model-parameters
        #loss.backward()
        loss.backward()
        # perform-a-ingle-optimization-step (parameter-update)
        optimizer.step()
        #scheduler.step()
        # update-training-loss
        train_loss += loss.item() * data.size(0)
        
    model.eval()
    for data, target in test_loader:
        
        data = data.to(device).float()
        target = target.to(device).float()
        #data=data.permute(0,3,1,2)
        outputte,mu2,logvar2,cnf2,z2,feat2 = model(data)
        
        loss=diceloss(outputte,target)+0.0001*kld_loss(mu2,logvar2)#+kdl_loss(gam2,adj2)
        
        # update-average-validation-loss 
        valid_loss += loss.item() * data.size(0)
    
    # calculate-average-losses
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(test_loader.sampler)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
        
    # print-training/validation-statistics 
    #print('Epoch-{0} lr: {1}'.format(epoch, optimizer.param_groups[0]['lr']))
    #print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch, train_loss, valid_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Streaming output truncated to the last 5000 lines.
# Epoch-2501 lr: 1e-05
# Epoch: 2501 	Training Loss: 0.285767 	Validation Loss: 0.288103
# Epoch-2502 lr: 1e-05
# Epoch: 2502 	Training Loss: 0.285901 	Validation Loss: 0.288113
# Epoch-2503 lr: 1e-05
# Epoch: 2503 	Training Loss: 0.284161 	Validation Loss: 0.288896
# Epoch-2504 lr: 1e-05
# Epoch: 2504 	Training Loss: 0.285349 	Validation Loss: 0.285175
# Epoch-2505 lr: 1e-05
# Epoch: 2505 	Training Loss: 0.284729 	Validation Loss: 0.285386
# Epoch-2506 lr: 1e-05
# Epoch: 2506 	Training Loss: 0.286796 	Validation Loss: 0.285209
# Epoch-2507 lr: 1e-05
# Epoch: 2507 	Training Loss: 0.284926 	Validation Loss: 0.287985
# Epoch-2508 lr: 1e-05
# Epoch: 2508 	Training Loss: 0.284304 	Validation Loss: 0.286653
# Epoch-2509 lr: 1e-05
# Epoch: 2509 	Training Loss: 0.283186 	Validation Loss: 0.287020
# Epoch-2510 lr: 1e-05
# Epoch: 2510 	Training Loss: 0.286935 	Validation Loss: 0.285815
# Epoch-2511 lr: 1e-05
# Epoch: 2511 	Training Loss: 0.285420 	Validation Loss: 0.287464
# Epoch-2512 lr: 1e-05
# Epoch: 2512 	Training Loss: 0.285697 	Validation Loss: 0.288139
# Epoch-2513 lr: 1e-05
# Epoch: 2513 	Training Loss: 0.286674 	Validation Loss: 0.282422
# Epoch-2514 lr: 1e-05
# Epoch: 2514 	Training Loss: 0.284659 	Validation Loss: 0.287311
# Epoch-2515 lr: 1e-05
# Epoch: 2515 	Training Loss: 0.285873 	Validation Loss: 0.286763
# Epoch-2516 lr: 1e-05
# Epoch: 2516 	Training Loss: 0.286107 	Validation Loss: 0.284934
# Epoch-2517 lr: 1e-05
# Epoch: 2517 	Training Loss: 0.283775 	Validation Loss: 0.286221
# Epoch-2518 lr: 1e-05
# Epoch: 2518 	Training Loss: 0.286223 	Validation Loss: 0.284022
# Epoch-2519 lr: 1e-05
# Epoch: 2519 	Training Loss: 0.286131 	Validation Loss: 0.287653
# Epoch-2520 lr: 1e-05
# Epoch: 2520 	Training Loss: 0.285235 	Validation Loss: 0.286826
# Epoch-2521 lr: 1e-05
# Epoch: 2521 	Training Loss: 0.285660 	Validation Loss: 0.290607
# Epoch-2522 lr: 1e-05
# Epoch: 2522 	Training Loss: 0.286262 	Validation Loss: 0.284975
# Epoch-2523 lr: 1e-05
# Epoch: 2523 	Training Loss: 0.282452 	Validation Loss: 0.283428
# Epoch-2524 lr: 1e-05
# Epoch: 2524 	Training Loss: 0.285763 	Validation Loss: 0.287379
# Epoch-2525 lr: 1e-05
# Epoch: 2525 	Training Loss: 0.286207 	Validation Loss: 0.286737
# Epoch-2526 lr: 1e-05
# Epoch: 2526 	Training Loss: 0.286102 	Validation Loss: 0.289556
# Epoch-2527 lr: 1e-05
# Epoch: 2527 	Training Loss: 0.283975 	Validation Loss: 0.290741
# Epoch-2528 lr: 1e-05
# Epoch: 2528 	Training Loss: 0.285770 	Validation Loss: 0.284429
# Epoch-2529 lr: 1e-05
# Epoch: 2529 	Training Loss: 0.286651 	Validation Loss: 0.289621
# Epoch-2530 lr: 1e-05
# Epoch: 2530 	Training Loss: 0.283462 	Validation Loss: 0.285845
# Epoch-2531 lr: 1e-05
# Epoch: 2531 	Training Loss: 0.286595 	Validation Loss: 0.284829
# Epoch-2532 lr: 1e-05
# Epoch: 2532 	Training Loss: 0.284988 	Validation Loss: 0.284755
# Epoch-2533 lr: 1e-05
# Epoch: 2533 	Training Loss: 0.284830 	Validation Loss: 0.285011
# Epoch-2534 lr: 1e-05
# Epoch: 2534 	Training Loss: 0.283322 	Validation Loss: 0.287434
# Epoch-2535 lr: 1e-05
# Epoch: 2535 	Training Loss: 0.284069 	Validation Loss: 0.284691
# Epoch-2536 lr: 1e-05
# Epoch: 2536 	Training Loss: 0.285752 	Validation Loss: 0.286689
# Epoch-2537 lr: 1e-05
# Epoch: 2537 	Training Loss: 0.284076 	Validation Loss: 0.288130
# Epoch-2538 lr: 1e-05
# Epoch: 2538 	Training Loss: 0.286098 	Validation Loss: 0.287384
# Epoch-2539 lr: 1e-05
# Epoch: 2539 	Training Loss: 0.287530 	Validation Loss: 0.282489
# Epoch-2540 lr: 1e-05
# Epoch: 2540 	Training Loss: 0.284851 	Validation Loss: 0.284444
# Epoch-2541 lr: 1e-05
# Epoch: 2541 	Training Loss: 0.283612 	Validation Loss: 0.286070
# Epoch-2542 lr: 1e-05
# Epoch: 2542 	Training Loss: 0.283511 	Validation Loss: 0.283972
# Epoch-2543 lr: 1e-05
# Epoch: 2543 	Training Loss: 0.284502 	Validation Loss: 0.286226
# Epoch-2544 lr: 1e-05
# Epoch: 2544 	Training Loss: 0.285490 	Validation Loss: 0.284965
# Epoch-2545 lr: 1e-05
# Epoch: 2545 	Training Loss: 0.285520 	Validation Loss: 0.290667
# Epoch-2546 lr: 1e-05
# Epoch: 2546 	Training Loss: 0.283857 	Validation Loss: 0.282596
# Epoch-2547 lr: 1e-05
# Epoch: 2547 	Training Loss: 0.287522 	Validation Loss: 0.290015
# Epoch-2548 lr: 1e-05
# Epoch: 2548 	Training Loss: 0.284928 	Validation Loss: 0.286196
# Epoch-2549 lr: 1e-05
# Epoch: 2549 	Training Loss: 0.284159 	Validation Loss: 0.290849
# Epoch-2550 lr: 1e-05
# Epoch: 2550 	Training Loss: 0.283377 	Validation Loss: 0.281209
# Epoch-2551 lr: 1e-05
# Epoch: 2551 	Training Loss: 0.287044 	Validation Loss: 0.286026
# Epoch-2552 lr: 1e-05
# Epoch: 2552 	Training Loss: 0.285755 	Validation Loss: 0.285161
# Epoch-2553 lr: 1e-05
# Epoch: 2553 	Training Loss: 0.284482 	Validation Loss: 0.284089
# Epoch-2554 lr: 1e-05
# Epoch: 2554 	Training Loss: 0.284900 	Validation Loss: 0.287012
# Epoch-2555 lr: 1e-05
# Epoch: 2555 	Training Loss: 0.283916 	Validation Loss: 0.286930
# Epoch-2556 lr: 1e-05
# Epoch: 2556 	Training Loss: 0.284516 	Validation Loss: 0.280570
# Epoch-2557 lr: 1e-05
# Epoch: 2557 	Training Loss: 0.283345 	Validation Loss: 0.287567
# Epoch-2558 lr: 1e-05
# Epoch: 2558 	Training Loss: 0.283081 	Validation Loss: 0.284647
# Epoch-2559 lr: 1e-05
# Epoch: 2559 	Training Loss: 0.284271 	Validation Loss: 0.282441
# Epoch-2560 lr: 1e-05
# Epoch: 2560 	Training Loss: 0.286479 	Validation Loss: 0.286076
# Epoch-2561 lr: 1e-05
# Epoch: 2561 	Training Loss: 0.284304 	Validation Loss: 0.281107
# Epoch-2562 lr: 1e-05
# Epoch: 2562 	Training Loss: 0.284357 	Validation Loss: 0.286955
# Epoch-2563 lr: 1e-05
# Epoch: 2563 	Training Loss: 0.283664 	Validation Loss: 0.283575
# Epoch-2564 lr: 1e-05
# Epoch: 2564 	Training Loss: 0.285561 	Validation Loss: 0.285419
# Epoch-2565 lr: 1e-05
# Epoch: 2565 	Training Loss: 0.283449 	Validation Loss: 0.281242
# Epoch-2566 lr: 1e-05
# Epoch: 2566 	Training Loss: 0.283180 	Validation Loss: 0.283293
# Epoch-2567 lr: 1e-05
# Epoch: 2567 	Training Loss: 0.283194 	Validation Loss: 0.286215
# Epoch-2568 lr: 1e-05
# Epoch: 2568 	Training Loss: 0.284418 	Validation Loss: 0.283159
# Epoch-2569 lr: 1e-05
# Epoch: 2569 	Training Loss: 0.283514 	Validation Loss: 0.288861
# Epoch-2570 lr: 1e-05
# Epoch: 2570 	Training Loss: 0.284583 	Validation Loss: 0.285049
# Epoch-2571 lr: 1e-05
# Epoch: 2571 	Training Loss: 0.282740 	Validation Loss: 0.285928
# Epoch-2572 lr: 1e-05
# Epoch: 2572 	Training Loss: 0.286595 	Validation Loss: 0.285524
# Epoch-2573 lr: 1e-05
# Epoch: 2573 	Training Loss: 0.285427 	Validation Loss: 0.284497
# Epoch-2574 lr: 1e-05
# Epoch: 2574 	Training Loss: 0.283526 	Validation Loss: 0.287517
# Epoch-2575 lr: 1e-05
# Epoch: 2575 	Training Loss: 0.282493 	Validation Loss: 0.282690
# Epoch-2576 lr: 1e-05
# Epoch: 2576 	Training Loss: 0.282808 	Validation Loss: 0.284441
# Epoch-2577 lr: 1e-05
# Epoch: 2577 	Training Loss: 0.282459 	Validation Loss: 0.286418
# Epoch-2578 lr: 1e-05
# Epoch: 2578 	Training Loss: 0.283838 	Validation Loss: 0.281814
# Epoch-2579 lr: 1e-05
# Epoch: 2579 	Training Loss: 0.283540 	Validation Loss: 0.283424
# Epoch-2580 lr: 1e-05
# Epoch: 2580 	Training Loss: 0.282264 	Validation Loss: 0.288042
# Epoch-2581 lr: 1e-05
# Epoch: 2581 	Training Loss: 0.284488 	Validation Loss: 0.288311
# Epoch-2582 lr: 1e-05
# Epoch: 2582 	Training Loss: 0.283770 	Validation Loss: 0.285228
# Epoch-2583 lr: 1e-05
# Epoch: 2583 	Training Loss: 0.284354 	Validation Loss: 0.285446
# Epoch-2584 lr: 1e-05
# Epoch: 2584 	Training Loss: 0.282896 	Validation Loss: 0.290718
# Epoch-2585 lr: 1e-05
# Epoch: 2585 	Training Loss: 0.287015 	Validation Loss: 0.292268
# Epoch-2586 lr: 1e-05
# Epoch: 2586 	Training Loss: 0.285101 	Validation Loss: 0.286078
# Epoch-2587 lr: 1e-05
# Epoch: 2587 	Training Loss: 0.287009 	Validation Loss: 0.284104
# Epoch-2588 lr: 1e-05
# Epoch: 2588 	Training Loss: 0.285724 	Validation Loss: 0.287800
# Epoch-2589 lr: 1e-05
# Epoch: 2589 	Training Loss: 0.284846 	Validation Loss: 0.283697
# Epoch-2590 lr: 1e-05
# Epoch: 2590 	Training Loss: 0.283109 	Validation Loss: 0.286579
# Epoch-2591 lr: 1e-05
# Epoch: 2591 	Training Loss: 0.283284 	Validation Loss: 0.285168
# Epoch-2592 lr: 1e-05
# Epoch: 2592 	Training Loss: 0.284174 	Validation Loss: 0.284809
# Epoch-2593 lr: 1e-05
# Epoch: 2593 	Training Loss: 0.285924 	Validation Loss: 0.289506
# Epoch-2594 lr: 1e-05
# Epoch: 2594 	Training Loss: 0.284701 	Validation Loss: 0.279819
# Epoch-2595 lr: 1e-05
# Epoch: 2595 	Training Loss: 0.283572 	Validation Loss: 0.281736
# Epoch-2596 lr: 1e-05
# Epoch: 2596 	Training Loss: 0.284048 	Validation Loss: 0.284142
# Epoch-2597 lr: 1e-05
# Epoch: 2597 	Training Loss: 0.282527 	Validation Loss: 0.285864
# Epoch-2598 lr: 1e-05
# Epoch: 2598 	Training Loss: 0.283138 	Validation Loss: 0.285527
# Epoch-2599 lr: 1e-05
# Epoch: 2599 	Training Loss: 0.282921 	Validation Loss: 0.285219
# Epoch-2600 lr: 1e-05
# Epoch: 2600 	Training Loss: 0.283775 	Validation Loss: 0.283694
# Epoch-2601 lr: 1e-05
# Epoch: 2601 	Training Loss: 0.283329 	Validation Loss: 0.290038
# Epoch-2602 lr: 1e-05
# Epoch: 2602 	Training Loss: 0.283344 	Validation Loss: 0.283146
# Epoch-2603 lr: 1e-05
# Epoch: 2603 	Training Loss: 0.282507 	Validation Loss: 0.286075
# Epoch-2604 lr: 1e-05
# Epoch: 2604 	Training Loss: 0.282938 	Validation Loss: 0.287208
# Epoch-2605 lr: 1e-05
# Epoch: 2605 	Training Loss: 0.284977 	Validation Loss: 0.287525
# Epoch-2606 lr: 1e-05
# Epoch: 2606 	Training Loss: 0.282519 	Validation Loss: 0.288020
# Epoch-2607 lr: 1e-05
# Epoch: 2607 	Training Loss: 0.283166 	Validation Loss: 0.282870
# Epoch-2608 lr: 1e-05
# Epoch: 2608 	Training Loss: 0.281621 	Validation Loss: 0.284780
# Epoch-2609 lr: 1e-05
# Epoch: 2609 	Training Loss: 0.282953 	Validation Loss: 0.282988
# Epoch-2610 lr: 1e-05
# Epoch: 2610 	Training Loss: 0.283070 	Validation Loss: 0.284287
# Epoch-2611 lr: 1e-05
# Epoch: 2611 	Training Loss: 0.285343 	Validation Loss: 0.285632
# Epoch-2612 lr: 1e-05
# Epoch: 2612 	Training Loss: 0.283372 	Validation Loss: 0.285245
# Epoch-2613 lr: 1e-05
# Epoch: 2613 	Training Loss: 0.286048 	Validation Loss: 0.284240
# Epoch-2614 lr: 1e-05
# Epoch: 2614 	Training Loss: 0.286658 	Validation Loss: 0.282129
# Epoch-2615 lr: 1e-05
# Epoch: 2615 	Training Loss: 0.283048 	Validation Loss: 0.285505
# Epoch-2616 lr: 1e-05
# Epoch: 2616 	Training Loss: 0.282593 	Validation Loss: 0.282596
# Epoch-2617 lr: 1e-05
# Epoch: 2617 	Training Loss: 0.283489 	Validation Loss: 0.286578
# Epoch-2618 lr: 1e-05
# Epoch: 2618 	Training Loss: 0.285668 	Validation Loss: 0.287415
# Epoch-2619 lr: 1e-05
# Epoch: 2619 	Training Loss: 0.282285 	Validation Loss: 0.287069
# Epoch-2620 lr: 1e-05
# Epoch: 2620 	Training Loss: 0.284029 	Validation Loss: 0.288284
# Epoch-2621 lr: 1e-05
# Epoch: 2621 	Training Loss: 0.283118 	Validation Loss: 0.283063
# Epoch-2622 lr: 1e-05
# Epoch: 2622 	Training Loss: 0.281371 	Validation Loss: 0.288018
# Epoch-2623 lr: 1e-05
# Epoch: 2623 	Training Loss: 0.282055 	Validation Loss: 0.287026
# Epoch-2624 lr: 1e-05
# Epoch: 2624 	Training Loss: 0.285386 	Validation Loss: 0.283403
# Epoch-2625 lr: 1e-05
# Epoch: 2625 	Training Loss: 0.283803 	Validation Loss: 0.287370
# Epoch-2626 lr: 1e-05
# Epoch: 2626 	Training Loss: 0.282661 	Validation Loss: 0.284379
# Epoch-2627 lr: 1e-05
# Epoch: 2627 	Training Loss: 0.282985 	Validation Loss: 0.278993
# Epoch-2628 lr: 1e-05
# Epoch: 2628 	Training Loss: 0.283913 	Validation Loss: 0.282866
# Epoch-2629 lr: 1e-05
# Epoch: 2629 	Training Loss: 0.283960 	Validation Loss: 0.288000
# Epoch-2630 lr: 1e-05
# Epoch: 2630 	Training Loss: 0.282303 	Validation Loss: 0.285828
# Epoch-2631 lr: 1e-05
# Epoch: 2631 	Training Loss: 0.281990 	Validation Loss: 0.280877
# Epoch-2632 lr: 1e-05
# Epoch: 2632 	Training Loss: 0.282556 	Validation Loss: 0.284689
# Epoch-2633 lr: 1e-05
# Epoch: 2633 	Training Loss: 0.282319 	Validation Loss: 0.286446
# Epoch-2634 lr: 1e-05
# Epoch: 2634 	Training Loss: 0.282790 	Validation Loss: 0.284749
# Epoch-2635 lr: 1e-05
# Epoch: 2635 	Training Loss: 0.282687 	Validation Loss: 0.287063
# Epoch-2636 lr: 1e-05
# Epoch: 2636 	Training Loss: 0.283398 	Validation Loss: 0.284164
# Epoch-2637 lr: 1e-05
# Epoch: 2637 	Training Loss: 0.280765 	Validation Loss: 0.282757
# Epoch-2638 lr: 1e-05
# Epoch: 2638 	Training Loss: 0.283632 	Validation Loss: 0.283456
# Epoch-2639 lr: 1e-05
# Epoch: 2639 	Training Loss: 0.283129 	Validation Loss: 0.287299
# Epoch-2640 lr: 1e-05
# Epoch: 2640 	Training Loss: 0.283391 	Validation Loss: 0.282934
# Epoch-2641 lr: 1e-05
# Epoch: 2641 	Training Loss: 0.281754 	Validation Loss: 0.285768
# Epoch-2642 lr: 1e-05
# Epoch: 2642 	Training Loss: 0.282239 	Validation Loss: 0.281969
# Epoch-2643 lr: 1e-05
# Epoch: 2643 	Training Loss: 0.283105 	Validation Loss: 0.286841
# Epoch-2644 lr: 1e-05
# Epoch: 2644 	Training Loss: 0.282910 	Validation Loss: 0.279757
# Epoch-2645 lr: 1e-05
# Epoch: 2645 	Training Loss: 0.282670 	Validation Loss: 0.282910
# Epoch-2646 lr: 1e-05
# Epoch: 2646 	Training Loss: 0.283923 	Validation Loss: 0.284418
# Epoch-2647 lr: 1e-05
# Epoch: 2647 	Training Loss: 0.285246 	Validation Loss: 0.287858
# Epoch-2648 lr: 1e-05
# Epoch: 2648 	Training Loss: 0.284460 	Validation Loss: 0.282606
# Epoch-2649 lr: 1e-05
# Epoch: 2649 	Training Loss: 0.282914 	Validation Loss: 0.282044
# Epoch-2650 lr: 1e-05
# Epoch: 2650 	Training Loss: 0.281938 	Validation Loss: 0.284258
# Epoch-2651 lr: 1e-05
# Epoch: 2651 	Training Loss: 0.283334 	Validation Loss: 0.283249
# Epoch-2652 lr: 1e-05
# Epoch: 2652 	Training Loss: 0.282661 	Validation Loss: 0.282132
# Epoch-2653 lr: 1e-05
# Epoch: 2653 	Training Loss: 0.281999 	Validation Loss: 0.281856
# Epoch-2654 lr: 1e-05
# Epoch: 2654 	Training Loss: 0.282896 	Validation Loss: 0.286375
# Epoch-2655 lr: 1e-05
# Epoch: 2655 	Training Loss: 0.282161 	Validation Loss: 0.283350
# Epoch-2656 lr: 1e-05
# Epoch: 2656 	Training Loss: 0.282584 	Validation Loss: 0.285900
# Epoch-2657 lr: 1e-05
# Epoch: 2657 	Training Loss: 0.284067 	Validation Loss: 0.282910
# Epoch-2658 lr: 1e-05
# Epoch: 2658 	Training Loss: 0.282376 	Validation Loss: 0.283326
# Epoch-2659 lr: 1e-05
# Epoch: 2659 	Training Loss: 0.282384 	Validation Loss: 0.284885
# Epoch-2660 lr: 1e-05
# Epoch: 2660 	Training Loss: 0.282051 	Validation Loss: 0.282828
# Epoch-2661 lr: 1e-05
# Epoch: 2661 	Training Loss: 0.284343 	Validation Loss: 0.284756
# Epoch-2662 lr: 1e-05
# Epoch: 2662 	Training Loss: 0.281567 	Validation Loss: 0.287180
# Epoch-2663 lr: 1e-05
# Epoch: 2663 	Training Loss: 0.283367 	Validation Loss: 0.284078
# Epoch-2664 lr: 1e-05
# Epoch: 2664 	Training Loss: 0.282625 	Validation Loss: 0.283213
# Epoch-2665 lr: 1e-05
# Epoch: 2665 	Training Loss: 0.282134 	Validation Loss: 0.282717
# Epoch-2666 lr: 1e-05
# Epoch: 2666 	Training Loss: 0.281602 	Validation Loss: 0.281156
# Epoch-2667 lr: 1e-05
# Epoch: 2667 	Training Loss: 0.284116 	Validation Loss: 0.281693
# Epoch-2668 lr: 1e-05
# Epoch: 2668 	Training Loss: 0.282993 	Validation Loss: 0.284929
# Epoch-2669 lr: 1e-05
# Epoch: 2669 	Training Loss: 0.281923 	Validation Loss: 0.284791
# Epoch-2670 lr: 1e-05
# Epoch: 2670 	Training Loss: 0.283048 	Validation Loss: 0.284439
# Epoch-2671 lr: 1e-05
# Epoch: 2671 	Training Loss: 0.282647 	Validation Loss: 0.286547
# Epoch-2672 lr: 1e-05
# Epoch: 2672 	Training Loss: 0.282036 	Validation Loss: 0.283929
# Epoch-2673 lr: 1e-05
# Epoch: 2673 	Training Loss: 0.279849 	Validation Loss: 0.280579
# Epoch-2674 lr: 1e-05
# Epoch: 2674 	Training Loss: 0.283868 	Validation Loss: 0.283565
# Epoch-2675 lr: 1e-05
# Epoch: 2675 	Training Loss: 0.282179 	Validation Loss: 0.283855
# Epoch-2676 lr: 1e-05
# Epoch: 2676 	Training Loss: 0.282250 	Validation Loss: 0.284266
# Epoch-2677 lr: 1e-05
# Epoch: 2677 	Training Loss: 0.280907 	Validation Loss: 0.285757
# Epoch-2678 lr: 1e-05
# Epoch: 2678 	Training Loss: 0.280563 	Validation Loss: 0.283546
# Epoch-2679 lr: 1e-05
# Epoch: 2679 	Training Loss: 0.281067 	Validation Loss: 0.285358
# Epoch-2680 lr: 1e-05
# Epoch: 2680 	Training Loss: 0.280962 	Validation Loss: 0.281817
# Epoch-2681 lr: 1e-05
# Epoch: 2681 	Training Loss: 0.282483 	Validation Loss: 0.281842
# Epoch-2682 lr: 1e-05
# Epoch: 2682 	Training Loss: 0.281371 	Validation Loss: 0.285779
# Epoch-2683 lr: 1e-05
# Epoch: 2683 	Training Loss: 0.281881 	Validation Loss: 0.285767
# Epoch-2684 lr: 1e-05
# Epoch: 2684 	Training Loss: 0.283523 	Validation Loss: 0.284650
# Epoch-2685 lr: 1e-05
# Epoch: 2685 	Training Loss: 0.282475 	Validation Loss: 0.285861
# Epoch-2686 lr: 1e-05
# Epoch: 2686 	Training Loss: 0.282963 	Validation Loss: 0.283305
# Epoch-2687 lr: 1e-05
# Epoch: 2687 	Training Loss: 0.282995 	Validation Loss: 0.285535
# Epoch-2688 lr: 1e-05
# Epoch: 2688 	Training Loss: 0.283567 	Validation Loss: 0.283364
# Epoch-2689 lr: 1e-05
# Epoch: 2689 	Training Loss: 0.282111 	Validation Loss: 0.280317
# Epoch-2690 lr: 1e-05
# Epoch: 2690 	Training Loss: 0.281799 	Validation Loss: 0.287841
# Epoch-2691 lr: 1e-05
# Epoch: 2691 	Training Loss: 0.284294 	Validation Loss: 0.286145
# Epoch-2692 lr: 1e-05
# Epoch: 2692 	Training Loss: 0.280591 	Validation Loss: 0.282705
# Epoch-2693 lr: 1e-05
# Epoch: 2693 	Training Loss: 0.281765 	Validation Loss: 0.286534
# Epoch-2694 lr: 1e-05
# Epoch: 2694 	Training Loss: 0.280996 	Validation Loss: 0.289442
# Epoch-2695 lr: 1e-05
# Epoch: 2695 	Training Loss: 0.282287 	Validation Loss: 0.285050
# Epoch-2696 lr: 1e-05
# Epoch: 2696 	Training Loss: 0.280973 	Validation Loss: 0.283755
# Epoch-2697 lr: 1e-05
# Epoch: 2697 	Training Loss: 0.282068 	Validation Loss: 0.284129
# Epoch-2698 lr: 1e-05
# Epoch: 2698 	Training Loss: 0.278961 	Validation Loss: 0.279682
# Epoch-2699 lr: 1e-05
# Epoch: 2699 	Training Loss: 0.281240 	Validation Loss: 0.284328
# Epoch-2700 lr: 1e-05
# Epoch: 2700 	Training Loss: 0.280606 	Validation Loss: 0.281855
# Epoch-2701 lr: 1e-05
# Epoch: 2701 	Training Loss: 0.282242 	Validation Loss: 0.283013
# Epoch-2702 lr: 1e-05
# Epoch: 2702 	Training Loss: 0.283387 	Validation Loss: 0.280727
# Epoch-2703 lr: 1e-05
# Epoch: 2703 	Training Loss: 0.281562 	Validation Loss: 0.282249
# Epoch-2704 lr: 1e-05
# Epoch: 2704 	Training Loss: 0.282379 	Validation Loss: 0.287558
# Epoch-2705 lr: 1e-05
# Epoch: 2705 	Training Loss: 0.281070 	Validation Loss: 0.283736
# Epoch-2706 lr: 1e-05
# Epoch: 2706 	Training Loss: 0.281010 	Validation Loss: 0.283733
# Epoch-2707 lr: 1e-05
# Epoch: 2707 	Training Loss: 0.281384 	Validation Loss: 0.283237
# Epoch-2708 lr: 1e-05
# Epoch: 2708 	Training Loss: 0.281662 	Validation Loss: 0.282474
# Epoch-2709 lr: 1e-05
# Epoch: 2709 	Training Loss: 0.281681 	Validation Loss: 0.285625
# Epoch-2710 lr: 1e-05
# Epoch: 2710 	Training Loss: 0.282789 	Validation Loss: 0.288779
# Epoch-2711 lr: 1e-05
# Epoch: 2711 	Training Loss: 0.281886 	Validation Loss: 0.286050
# Epoch-2712 lr: 1e-05
# Epoch: 2712 	Training Loss: 0.281816 	Validation Loss: 0.283604
# Epoch-2713 lr: 1e-05
# Epoch: 2713 	Training Loss: 0.279547 	Validation Loss: 0.280843
# Epoch-2714 lr: 1e-05
# Epoch: 2714 	Training Loss: 0.282875 	Validation Loss: 0.285033
# Epoch-2715 lr: 1e-05
# Epoch: 2715 	Training Loss: 0.281146 	Validation Loss: 0.288406
# Epoch-2716 lr: 1e-05
# Epoch: 2716 	Training Loss: 0.283241 	Validation Loss: 0.283313
# Epoch-2717 lr: 1e-05
# Epoch: 2717 	Training Loss: 0.282454 	Validation Loss: 0.281414
# Epoch-2718 lr: 1e-05
# Epoch: 2718 	Training Loss: 0.282886 	Validation Loss: 0.279587
# Epoch-2719 lr: 1e-05
# Epoch: 2719 	Training Loss: 0.282469 	Validation Loss: 0.280850
# Epoch-2720 lr: 1e-05
# Epoch: 2720 	Training Loss: 0.281711 	Validation Loss: 0.280104
# Epoch-2721 lr: 1e-05
# Epoch: 2721 	Training Loss: 0.284756 	Validation Loss: 0.292919
# Epoch-2722 lr: 1e-05
# Epoch: 2722 	Training Loss: 0.284007 	Validation Loss: 0.279696
# Epoch-2723 lr: 1e-05
# Epoch: 2723 	Training Loss: 0.281827 	Validation Loss: 0.282945
# Epoch-2724 lr: 1e-05
# Epoch: 2724 	Training Loss: 0.282455 	Validation Loss: 0.285198
# Epoch-2725 lr: 1e-05
# Epoch: 2725 	Training Loss: 0.281933 	Validation Loss: 0.284446
# Epoch-2726 lr: 1e-05
# Epoch: 2726 	Training Loss: 0.282685 	Validation Loss: 0.286272
# Epoch-2727 lr: 1e-05
# Epoch: 2727 	Training Loss: 0.282096 	Validation Loss: 0.282956
# Epoch-2728 lr: 1e-05
# Epoch: 2728 	Training Loss: 0.281185 	Validation Loss: 0.282405
# Epoch-2729 lr: 1e-05
# Epoch: 2729 	Training Loss: 0.281466 	Validation Loss: 0.284983
# Epoch-2730 lr: 1e-05
# Epoch: 2730 	Training Loss: 0.282212 	Validation Loss: 0.284452
# Epoch-2731 lr: 1e-05
# Epoch: 2731 	Training Loss: 0.279473 	Validation Loss: 0.285334
# Epoch-2732 lr: 1e-05
# Epoch: 2732 	Training Loss: 0.279387 	Validation Loss: 0.285648
# Epoch-2733 lr: 1e-05
# Epoch: 2733 	Training Loss: 0.281966 	Validation Loss: 0.281880
# Epoch-2734 lr: 1e-05
# Epoch: 2734 	Training Loss: 0.280924 	Validation Loss: 0.286875
# Epoch-2735 lr: 1e-05
# Epoch: 2735 	Training Loss: 0.281720 	Validation Loss: 0.283710
# Epoch-2736 lr: 1e-05
# Epoch: 2736 	Training Loss: 0.280930 	Validation Loss: 0.287111
# Epoch-2737 lr: 1e-05
# Epoch: 2737 	Training Loss: 0.282347 	Validation Loss: 0.288518
# Epoch-2738 lr: 1e-05
# Epoch: 2738 	Training Loss: 0.282229 	Validation Loss: 0.281652
# Epoch-2739 lr: 1e-05
# Epoch: 2739 	Training Loss: 0.278502 	Validation Loss: 0.281219
# Epoch-2740 lr: 1e-05
# Epoch: 2740 	Training Loss: 0.281398 	Validation Loss: 0.282446
# Epoch-2741 lr: 1e-05
# Epoch: 2741 	Training Loss: 0.280347 	Validation Loss: 0.283704
# Epoch-2742 lr: 1e-05
# Epoch: 2742 	Training Loss: 0.281882 	Validation Loss: 0.283460
# Epoch-2743 lr: 1e-05
# Epoch: 2743 	Training Loss: 0.283437 	Validation Loss: 0.284433
# Epoch-2744 lr: 1e-05
# Epoch: 2744 	Training Loss: 0.280595 	Validation Loss: 0.280580
# Epoch-2745 lr: 1e-05
# Epoch: 2745 	Training Loss: 0.280897 	Validation Loss: 0.281403
# Epoch-2746 lr: 1e-05
# Epoch: 2746 	Training Loss: 0.281946 	Validation Loss: 0.282192
# Epoch-2747 lr: 1e-05
# Epoch: 2747 	Training Loss: 0.280436 	Validation Loss: 0.283949
# Epoch-2748 lr: 1e-05
# Epoch: 2748 	Training Loss: 0.279938 	Validation Loss: 0.285226
# Epoch-2749 lr: 1e-05
# Epoch: 2749 	Training Loss: 0.282275 	Validation Loss: 0.283654
# Epoch-2750 lr: 1e-05
# Epoch: 2750 	Training Loss: 0.281824 	Validation Loss: 0.286206
# Epoch-2751 lr: 1e-05
# Epoch: 2751 	Training Loss: 0.280151 	Validation Loss: 0.284422
# Epoch-2752 lr: 1e-05
# Epoch: 2752 	Training Loss: 0.279876 	Validation Loss: 0.279768
# Epoch-2753 lr: 1e-05
# Epoch: 2753 	Training Loss: 0.281001 	Validation Loss: 0.281757
# Epoch-2754 lr: 1e-05
# Epoch: 2754 	Training Loss: 0.283772 	Validation Loss: 0.280651
# Epoch-2755 lr: 1e-05
# Epoch: 2755 	Training Loss: 0.281628 	Validation Loss: 0.285648
# Epoch-2756 lr: 1e-05
# Epoch: 2756 	Training Loss: 0.280694 	Validation Loss: 0.283981
# Epoch-2757 lr: 1e-05
# Epoch: 2757 	Training Loss: 0.281614 	Validation Loss: 0.284109
# Epoch-2758 lr: 1e-05
# Epoch: 2758 	Training Loss: 0.280587 	Validation Loss: 0.282395
# Epoch-2759 lr: 1e-05
# Epoch: 2759 	Training Loss: 0.280872 	Validation Loss: 0.283300
# Epoch-2760 lr: 1e-05
# Epoch: 2760 	Training Loss: 0.282510 	Validation Loss: 0.285032
# Epoch-2761 lr: 1e-05
# Epoch: 2761 	Training Loss: 0.282682 	Validation Loss: 0.282006
# Epoch-2762 lr: 1e-05
# Epoch: 2762 	Training Loss: 0.281520 	Validation Loss: 0.278800
# Epoch-2763 lr: 1e-05
# Epoch: 2763 	Training Loss: 0.280759 	Validation Loss: 0.283862
# Epoch-2764 lr: 1e-05
# Epoch: 2764 	Training Loss: 0.279607 	Validation Loss: 0.283637
# Epoch-2765 lr: 1e-05
# Epoch: 2765 	Training Loss: 0.281748 	Validation Loss: 0.283062
# Epoch-2766 lr: 1e-05
# Epoch: 2766 	Training Loss: 0.279921 	Validation Loss: 0.283173
# Epoch-2767 lr: 1e-05
# Epoch: 2767 	Training Loss: 0.280858 	Validation Loss: 0.283640
# Epoch-2768 lr: 1e-05
# Epoch: 2768 	Training Loss: 0.280340 	Validation Loss: 0.285577
# Epoch-2769 lr: 1e-05
# Epoch: 2769 	Training Loss: 0.280993 	Validation Loss: 0.283454
# Epoch-2770 lr: 1e-05
# Epoch: 2770 	Training Loss: 0.277955 	Validation Loss: 0.282511
# Epoch-2771 lr: 1e-05
# Epoch: 2771 	Training Loss: 0.278488 	Validation Loss: 0.282913
# Epoch-2772 lr: 1e-05
# Epoch: 2772 	Training Loss: 0.280043 	Validation Loss: 0.278640
# Epoch-2773 lr: 1e-05
# Epoch: 2773 	Training Loss: 0.280940 	Validation Loss: 0.283143
# Epoch-2774 lr: 1e-05
# Epoch: 2774 	Training Loss: 0.279276 	Validation Loss: 0.283447
# Epoch-2775 lr: 1e-05
# Epoch: 2775 	Training Loss: 0.279592 	Validation Loss: 0.283194
# Epoch-2776 lr: 1e-05
# Epoch: 2776 	Training Loss: 0.280828 	Validation Loss: 0.286350
# Epoch-2777 lr: 1e-05
# Epoch: 2777 	Training Loss: 0.280918 	Validation Loss: 0.282376
# Epoch-2778 lr: 1e-05
# Epoch: 2778 	Training Loss: 0.280717 	Validation Loss: 0.280774
# Epoch-2779 lr: 1e-05
# Epoch: 2779 	Training Loss: 0.278980 	Validation Loss: 0.283923
# Epoch-2780 lr: 1e-05
# Epoch: 2780 	Training Loss: 0.279978 	Validation Loss: 0.284882
# Epoch-2781 lr: 1e-05
# Epoch: 2781 	Training Loss: 0.280515 	Validation Loss: 0.284714
# Epoch-2782 lr: 1e-05
# Epoch: 2782 	Training Loss: 0.281198 	Validation Loss: 0.280087
# Epoch-2783 lr: 1e-05
# Epoch: 2783 	Training Loss: 0.279938 	Validation Loss: 0.283212
# Epoch-2784 lr: 1e-05
# Epoch: 2784 	Training Loss: 0.281805 	Validation Loss: 0.282586
# Epoch-2785 lr: 1e-05
# Epoch: 2785 	Training Loss: 0.279916 	Validation Loss: 0.281038
# Epoch-2786 lr: 1e-05
# Epoch: 2786 	Training Loss: 0.280859 	Validation Loss: 0.283959
# Epoch-2787 lr: 1e-05
# Epoch: 2787 	Training Loss: 0.281773 	Validation Loss: 0.285556
# Epoch-2788 lr: 1e-05
# Epoch: 2788 	Training Loss: 0.280920 	Validation Loss: 0.281164
# Epoch-2789 lr: 1e-05
# Epoch: 2789 	Training Loss: 0.279854 	Validation Loss: 0.280231
# Epoch-2790 lr: 1e-05
# Epoch: 2790 	Training Loss: 0.280011 	Validation Loss: 0.284677
# Epoch-2791 lr: 1e-05
# Epoch: 2791 	Training Loss: 0.280535 	Validation Loss: 0.280386
# Epoch-2792 lr: 1e-05
# Epoch: 2792 	Training Loss: 0.282100 	Validation Loss: 0.283693
# Epoch-2793 lr: 1e-05
# Epoch: 2793 	Training Loss: 0.278121 	Validation Loss: 0.281552
# Epoch-2794 lr: 1e-05
# Epoch: 2794 	Training Loss: 0.278394 	Validation Loss: 0.285611
# Epoch-2795 lr: 1e-05
# Epoch: 2795 	Training Loss: 0.281213 	Validation Loss: 0.284924
# Epoch-2796 lr: 1e-05
# Epoch: 2796 	Training Loss: 0.280396 	Validation Loss: 0.281852
# Epoch-2797 lr: 1e-05
# Epoch: 2797 	Training Loss: 0.279711 	Validation Loss: 0.283292
# Epoch-2798 lr: 1e-05
# Epoch: 2798 	Training Loss: 0.279919 	Validation Loss: 0.276763
# Epoch-2799 lr: 1e-05
# Epoch: 2799 	Training Loss: 0.279071 	Validation Loss: 0.285486
# Epoch-2800 lr: 1e-05
# Epoch: 2800 	Training Loss: 0.280319 	Validation Loss: 0.281808
# Epoch-2801 lr: 1e-05
# Epoch: 2801 	Training Loss: 0.279970 	Validation Loss: 0.281261
# Epoch-2802 lr: 1e-05
# Epoch: 2802 	Training Loss: 0.279519 	Validation Loss: 0.281211
# Epoch-2803 lr: 1e-05
# Epoch: 2803 	Training Loss: 0.279668 	Validation Loss: 0.282602
# Epoch-2804 lr: 1e-05
# Epoch: 2804 	Training Loss: 0.280414 	Validation Loss: 0.282419
# Epoch-2805 lr: 1e-05
# Epoch: 2805 	Training Loss: 0.278640 	Validation Loss: 0.282421
# Epoch-2806 lr: 1e-05
# Epoch: 2806 	Training Loss: 0.281564 	Validation Loss: 0.285331
# Epoch-2807 lr: 1e-05
# Epoch: 2807 	Training Loss: 0.282727 	Validation Loss: 0.277773
# Epoch-2808 lr: 1e-05
# Epoch: 2808 	Training Loss: 0.279615 	Validation Loss: 0.281161
# Epoch-2809 lr: 1e-05
# Epoch: 2809 	Training Loss: 0.279876 	Validation Loss: 0.284721
# Epoch-2810 lr: 1e-05
# Epoch: 2810 	Training Loss: 0.279666 	Validation Loss: 0.281473
# Epoch-2811 lr: 1e-05
# Epoch: 2811 	Training Loss: 0.279429 	Validation Loss: 0.278867
# Epoch-2812 lr: 1e-05
# Epoch: 2812 	Training Loss: 0.280571 	Validation Loss: 0.287195
# Epoch-2813 lr: 1e-05
# Epoch: 2813 	Training Loss: 0.282269 	Validation Loss: 0.286152
# Epoch-2814 lr: 1e-05
# Epoch: 2814 	Training Loss: 0.279373 	Validation Loss: 0.282417
# Epoch-2815 lr: 1e-05
# Epoch: 2815 	Training Loss: 0.279204 	Validation Loss: 0.278868
# Epoch-2816 lr: 1e-05
# Epoch: 2816 	Training Loss: 0.279373 	Validation Loss: 0.279752
# Epoch-2817 lr: 1e-05
# Epoch: 2817 	Training Loss: 0.279560 	Validation Loss: 0.281339
# Epoch-2818 lr: 1e-05
# Epoch: 2818 	Training Loss: 0.278791 	Validation Loss: 0.284488
# Epoch-2819 lr: 1e-05
# Epoch: 2819 	Training Loss: 0.279443 	Validation Loss: 0.284280
# Epoch-2820 lr: 1e-05
# Epoch: 2820 	Training Loss: 0.280004 	Validation Loss: 0.289054
# Epoch-2821 lr: 1e-05
# Epoch: 2821 	Training Loss: 0.280246 	Validation Loss: 0.283046
# Epoch-2822 lr: 1e-05
# Epoch: 2822 	Training Loss: 0.281807 	Validation Loss: 0.282535
# Epoch-2823 lr: 1e-05
# Epoch: 2823 	Training Loss: 0.278672 	Validation Loss: 0.281249
# Epoch-2824 lr: 1e-05
# Epoch: 2824 	Training Loss: 0.278017 	Validation Loss: 0.285214
# Epoch-2825 lr: 1e-05
# Epoch: 2825 	Training Loss: 0.280503 	Validation Loss: 0.284180
# Epoch-2826 lr: 1e-05
# Epoch: 2826 	Training Loss: 0.278157 	Validation Loss: 0.276849
# Epoch-2827 lr: 1e-05
# Epoch: 2827 	Training Loss: 0.279629 	Validation Loss: 0.281240
# Epoch-2828 lr: 1e-05
# Epoch: 2828 	Training Loss: 0.279652 	Validation Loss: 0.279135
# Epoch-2829 lr: 1e-05
# Epoch: 2829 	Training Loss: 0.280629 	Validation Loss: 0.287781
# Epoch-2830 lr: 1e-05
# Epoch: 2830 	Training Loss: 0.277527 	Validation Loss: 0.278802
# Epoch-2831 lr: 1e-05
# Epoch: 2831 	Training Loss: 0.279779 	Validation Loss: 0.283118
# Epoch-2832 lr: 1e-05
# Epoch: 2832 	Training Loss: 0.280502 	Validation Loss: 0.281489
# Epoch-2833 lr: 1e-05
# Epoch: 2833 	Training Loss: 0.279846 	Validation Loss: 0.281506
# Epoch-2834 lr: 1e-05
# Epoch: 2834 	Training Loss: 0.278979 	Validation Loss: 0.282507
# Epoch-2835 lr: 1e-05
# Epoch: 2835 	Training Loss: 0.278151 	Validation Loss: 0.282768
# Epoch-2836 lr: 1e-05
# Epoch: 2836 	Training Loss: 0.277328 	Validation Loss: 0.280931
# Epoch-2837 lr: 1e-05
# Epoch: 2837 	Training Loss: 0.280273 	Validation Loss: 0.281716
# Epoch-2838 lr: 1e-05
# Epoch: 2838 	Training Loss: 0.280503 	Validation Loss: 0.281281
# Epoch-2839 lr: 1e-05
# Epoch: 2839 	Training Loss: 0.277885 	Validation Loss: 0.284993
# Epoch-2840 lr: 1e-05
# Epoch: 2840 	Training Loss: 0.280209 	Validation Loss: 0.285955
# Epoch-2841 lr: 1e-05
# Epoch: 2841 	Training Loss: 0.276722 	Validation Loss: 0.279897
# Epoch-2842 lr: 1e-05
# Epoch: 2842 	Training Loss: 0.280215 	Validation Loss: 0.283320
# Epoch-2843 lr: 1e-05
# Epoch: 2843 	Training Loss: 0.281069 	Validation Loss: 0.283321
# Epoch-2844 lr: 1e-05
# Epoch: 2844 	Training Loss: 0.279283 	Validation Loss: 0.281783
# Epoch-2845 lr: 1e-05
# Epoch: 2845 	Training Loss: 0.279553 	Validation Loss: 0.282580
# Epoch-2846 lr: 1e-05
# Epoch: 2846 	Training Loss: 0.278230 	Validation Loss: 0.283529
# Epoch-2847 lr: 1e-05
# Epoch: 2847 	Training Loss: 0.278592 	Validation Loss: 0.284017
# Epoch-2848 lr: 1e-05
# Epoch: 2848 	Training Loss: 0.277736 	Validation Loss: 0.282620
# Epoch-2849 lr: 1e-05
# Epoch: 2849 	Training Loss: 0.279099 	Validation Loss: 0.281483
# Epoch-2850 lr: 1e-05
# Epoch: 2850 	Training Loss: 0.278141 	Validation Loss: 0.284003
# Epoch-2851 lr: 1e-05
# Epoch: 2851 	Training Loss: 0.277985 	Validation Loss: 0.280347
# Epoch-2852 lr: 1e-05
# Epoch: 2852 	Training Loss: 0.279391 	Validation Loss: 0.284177
# Epoch-2853 lr: 1e-05
# Epoch: 2853 	Training Loss: 0.277911 	Validation Loss: 0.279656
# Epoch-2854 lr: 1e-05
# Epoch: 2854 	Training Loss: 0.277623 	Validation Loss: 0.282272
# Epoch-2855 lr: 1e-05
# Epoch: 2855 	Training Loss: 0.278369 	Validation Loss: 0.283334
# Epoch-2856 lr: 1e-05
# Epoch: 2856 	Training Loss: 0.277393 	Validation Loss: 0.277248
# Epoch-2857 lr: 1e-05
# Epoch: 2857 	Training Loss: 0.278860 	Validation Loss: 0.283157
# Epoch-2858 lr: 1e-05
# Epoch: 2858 	Training Loss: 0.279206 	Validation Loss: 0.279700
# Epoch-2859 lr: 1e-05
# Epoch: 2859 	Training Loss: 0.278131 	Validation Loss: 0.279768
# Epoch-2860 lr: 1e-05
# Epoch: 2860 	Training Loss: 0.277731 	Validation Loss: 0.287522
# Epoch-2861 lr: 1e-05
# Epoch: 2861 	Training Loss: 0.279501 	Validation Loss: 0.289034
# Epoch-2862 lr: 1e-05
# Epoch: 2862 	Training Loss: 0.278476 	Validation Loss: 0.281702
# Epoch-2863 lr: 1e-05
# Epoch: 2863 	Training Loss: 0.278686 	Validation Loss: 0.283298
# Epoch-2864 lr: 1e-05
# Epoch: 2864 	Training Loss: 0.278911 	Validation Loss: 0.280048
# Epoch-2865 lr: 1e-05
# Epoch: 2865 	Training Loss: 0.279158 	Validation Loss: 0.280479
# Epoch-2866 lr: 1e-05
# Epoch: 2866 	Training Loss: 0.278760 	Validation Loss: 0.279280
# Epoch-2867 lr: 1e-05
# Epoch: 2867 	Training Loss: 0.278106 	Validation Loss: 0.283084
# Epoch-2868 lr: 1e-05
# Epoch: 2868 	Training Loss: 0.277110 	Validation Loss: 0.280296
# Epoch-2869 lr: 1e-05
# Epoch: 2869 	Training Loss: 0.278486 	Validation Loss: 0.285772
# Epoch-2870 lr: 1e-05
# Epoch: 2870 	Training Loss: 0.279329 	Validation Loss: 0.281868
# Epoch-2871 lr: 1e-05
# Epoch: 2871 	Training Loss: 0.277467 	Validation Loss: 0.278470
# Epoch-2872 lr: 1e-05
# Epoch: 2872 	Training Loss: 0.278646 	Validation Loss: 0.280953
# Epoch-2873 lr: 1e-05
# Epoch: 2873 	Training Loss: 0.278659 	Validation Loss: 0.281570
# Epoch-2874 lr: 1e-05
# Epoch: 2874 	Training Loss: 0.276010 	Validation Loss: 0.281201
# Epoch-2875 lr: 1e-05
# Epoch: 2875 	Training Loss: 0.277672 	Validation Loss: 0.280449
# Epoch-2876 lr: 1e-05
# Epoch: 2876 	Training Loss: 0.277557 	Validation Loss: 0.284879
# Epoch-2877 lr: 1e-05
# Epoch: 2877 	Training Loss: 0.279322 	Validation Loss: 0.282557
# Epoch-2878 lr: 1e-05
# Epoch: 2878 	Training Loss: 0.277038 	Validation Loss: 0.278449
# Epoch-2879 lr: 1e-05
# Epoch: 2879 	Training Loss: 0.277082 	Validation Loss: 0.284078
# Epoch-2880 lr: 1e-05
# Epoch: 2880 	Training Loss: 0.277884 	Validation Loss: 0.281144
# Epoch-2881 lr: 1e-05
# Epoch: 2881 	Training Loss: 0.277605 	Validation Loss: 0.280525
# Epoch-2882 lr: 1e-05
# Epoch: 2882 	Training Loss: 0.280048 	Validation Loss: 0.287605
# Epoch-2883 lr: 1e-05
# Epoch: 2883 	Training Loss: 0.278216 	Validation Loss: 0.283158
# Epoch-2884 lr: 1e-05
# Epoch: 2884 	Training Loss: 0.277088 	Validation Loss: 0.277644
# Epoch-2885 lr: 1e-05
# Epoch: 2885 	Training Loss: 0.277274 	Validation Loss: 0.285465
# Epoch-2886 lr: 1e-05
# Epoch: 2886 	Training Loss: 0.278981 	Validation Loss: 0.277852
# Epoch-2887 lr: 1e-05
# Epoch: 2887 	Training Loss: 0.277827 	Validation Loss: 0.277857
# Epoch-2888 lr: 1e-05
# Epoch: 2888 	Training Loss: 0.277767 	Validation Loss: 0.280531
# Epoch-2889 lr: 1e-05
# Epoch: 2889 	Training Loss: 0.277138 	Validation Loss: 0.285032
# Epoch-2890 lr: 1e-05
# Epoch: 2890 	Training Loss: 0.278530 	Validation Loss: 0.282185
# Epoch-2891 lr: 1e-05
# Epoch: 2891 	Training Loss: 0.277593 	Validation Loss: 0.284306
# Epoch-2892 lr: 1e-05
# Epoch: 2892 	Training Loss: 0.277769 	Validation Loss: 0.280113
# Epoch-2893 lr: 1e-05
# Epoch: 2893 	Training Loss: 0.277224 	Validation Loss: 0.280361
# Epoch-2894 lr: 1e-05
# Epoch: 2894 	Training Loss: 0.279628 	Validation Loss: 0.284202
# Epoch-2895 lr: 1e-05
# Epoch: 2895 	Training Loss: 0.278161 	Validation Loss: 0.279179
# Epoch-2896 lr: 1e-05
# Epoch: 2896 	Training Loss: 0.276882 	Validation Loss: 0.278812
# Epoch-2897 lr: 1e-05
# Epoch: 2897 	Training Loss: 0.277333 	Validation Loss: 0.282454
# Epoch-2898 lr: 1e-05
# Epoch: 2898 	Training Loss: 0.277303 	Validation Loss: 0.281516
# Epoch-2899 lr: 1e-05
# Epoch: 2899 	Training Loss: 0.276628 	Validation Loss: 0.285023
# Epoch-2900 lr: 1e-05
# Epoch: 2900 	Training Loss: 0.276567 	Validation Loss: 0.280250
# Epoch-2901 lr: 1e-05
# Epoch: 2901 	Training Loss: 0.277317 	Validation Loss: 0.284656
# Epoch-2902 lr: 1e-05
# Epoch: 2902 	Training Loss: 0.277257 	Validation Loss: 0.281872
# Epoch-2903 lr: 1e-05
# Epoch: 2903 	Training Loss: 0.278899 	Validation Loss: 0.280556
# Epoch-2904 lr: 1e-05
# Epoch: 2904 	Training Loss: 0.277186 	Validation Loss: 0.283462
# Epoch-2905 lr: 1e-05
# Epoch: 2905 	Training Loss: 0.276646 	Validation Loss: 0.280536
# Epoch-2906 lr: 1e-05
# Epoch: 2906 	Training Loss: 0.276962 	Validation Loss: 0.285554
# Epoch-2907 lr: 1e-05
# Epoch: 2907 	Training Loss: 0.277604 	Validation Loss: 0.278767
# Epoch-2908 lr: 1e-05
# Epoch: 2908 	Training Loss: 0.278099 	Validation Loss: 0.283895
# Epoch-2909 lr: 1e-05
# Epoch: 2909 	Training Loss: 0.278170 	Validation Loss: 0.283870
# Epoch-2910 lr: 1e-05
# Epoch: 2910 	Training Loss: 0.277153 	Validation Loss: 0.281973
# Epoch-2911 lr: 1e-05
# Epoch: 2911 	Training Loss: 0.278170 	Validation Loss: 0.287960
# Epoch-2912 lr: 1e-05
# Epoch: 2912 	Training Loss: 0.276657 	Validation Loss: 0.282405
# Epoch-2913 lr: 1e-05
# Epoch: 2913 	Training Loss: 0.279678 	Validation Loss: 0.282970
# Epoch-2914 lr: 1e-05
# Epoch: 2914 	Training Loss: 0.277511 	Validation Loss: 0.283791
# Epoch-2915 lr: 1e-05
# Epoch: 2915 	Training Loss: 0.279225 	Validation Loss: 0.284567
# Epoch-2916 lr: 1e-05
# Epoch: 2916 	Training Loss: 0.278070 	Validation Loss: 0.281704
# Epoch-2917 lr: 1e-05
# Epoch: 2917 	Training Loss: 0.276403 	Validation Loss: 0.279660
# Epoch-2918 lr: 1e-05
# Epoch: 2918 	Training Loss: 0.277522 	Validation Loss: 0.280748
# Epoch-2919 lr: 1e-05
# Epoch: 2919 	Training Loss: 0.277136 	Validation Loss: 0.275841
# Epoch-2920 lr: 1e-05
# Epoch: 2920 	Training Loss: 0.277172 	Validation Loss: 0.282604
# Epoch-2921 lr: 1e-05
# Epoch: 2921 	Training Loss: 0.277472 	Validation Loss: 0.281439
# Epoch-2922 lr: 1e-05
# Epoch: 2922 	Training Loss: 0.276267 	Validation Loss: 0.282821
# Epoch-2923 lr: 1e-05
# Epoch: 2923 	Training Loss: 0.279249 	Validation Loss: 0.283457
# Epoch-2924 lr: 1e-05
# Epoch: 2924 	Training Loss: 0.277366 	Validation Loss: 0.283363
# Epoch-2925 lr: 1e-05
# Epoch: 2925 	Training Loss: 0.276163 	Validation Loss: 0.280298
# Epoch-2926 lr: 1e-05
# Epoch: 2926 	Training Loss: 0.276520 	Validation Loss: 0.280781
# Epoch-2927 lr: 1e-05
# Epoch: 2927 	Training Loss: 0.275818 	Validation Loss: 0.281505
# Epoch-2928 lr: 1e-05
# Epoch: 2928 	Training Loss: 0.278013 	Validation Loss: 0.276862
# Epoch-2929 lr: 1e-05
# Epoch: 2929 	Training Loss: 0.278619 	Validation Loss: 0.284530
# Epoch-2930 lr: 1e-05
# Epoch: 2930 	Training Loss: 0.277064 	Validation Loss: 0.279849
# Epoch-2931 lr: 1e-05
# Epoch: 2931 	Training Loss: 0.279109 	Validation Loss: 0.281365
# Epoch-2932 lr: 1e-05
# Epoch: 2932 	Training Loss: 0.277633 	Validation Loss: 0.278556
# Epoch-2933 lr: 1e-05
# Epoch: 2933 	Training Loss: 0.276349 	Validation Loss: 0.280310
# Epoch-2934 lr: 1e-05
# Epoch: 2934 	Training Loss: 0.275175 	Validation Loss: 0.279311
# Epoch-2935 lr: 1e-05
# Epoch: 2935 	Training Loss: 0.277324 	Validation Loss: 0.279598
# Epoch-2936 lr: 1e-05
# Epoch: 2936 	Training Loss: 0.277583 	Validation Loss: 0.281906
# Epoch-2937 lr: 1e-05
# Epoch: 2937 	Training Loss: 0.279705 	Validation Loss: 0.279936
# Epoch-2938 lr: 1e-05
# Epoch: 2938 	Training Loss: 0.277853 	Validation Loss: 0.279460
# Epoch-2939 lr: 1e-05
# Epoch: 2939 	Training Loss: 0.277053 	Validation Loss: 0.277325
# Epoch-2940 lr: 1e-05
# Epoch: 2940 	Training Loss: 0.277719 	Validation Loss: 0.278401
# Epoch-2941 lr: 1e-05
# Epoch: 2941 	Training Loss: 0.276880 	Validation Loss: 0.276933
# Epoch-2942 lr: 1e-05
# Epoch: 2942 	Training Loss: 0.277711 	Validation Loss: 0.281752
# Epoch-2943 lr: 1e-05
# Epoch: 2943 	Training Loss: 0.275928 	Validation Loss: 0.281683
# Epoch-2944 lr: 1e-05
# Epoch: 2944 	Training Loss: 0.277641 	Validation Loss: 0.279028
# Epoch-2945 lr: 1e-05
# Epoch: 2945 	Training Loss: 0.276479 	Validation Loss: 0.280786
# Epoch-2946 lr: 1e-05
# Epoch: 2946 	Training Loss: 0.278243 	Validation Loss: 0.281554
# Epoch-2947 lr: 1e-05
# Epoch: 2947 	Training Loss: 0.279061 	Validation Loss: 0.280585
# Epoch-2948 lr: 1e-05
# Epoch: 2948 	Training Loss: 0.275817 	Validation Loss: 0.283419
# Epoch-2949 lr: 1e-05
# Epoch: 2949 	Training Loss: 0.276741 	Validation Loss: 0.279093
# Epoch-2950 lr: 1e-05
# Epoch: 2950 	Training Loss: 0.277370 	Validation Loss: 0.281064
# Epoch-2951 lr: 1e-05
# Epoch: 2951 	Training Loss: 0.277134 	Validation Loss: 0.277243
# Epoch-2952 lr: 1e-05
# Epoch: 2952 	Training Loss: 0.277746 	Validation Loss: 0.279380
# Epoch-2953 lr: 1e-05
# Epoch: 2953 	Training Loss: 0.276381 	Validation Loss: 0.285430
# Epoch-2954 lr: 1e-05
# Epoch: 2954 	Training Loss: 0.276862 	Validation Loss: 0.280091
# Epoch-2955 lr: 1e-05
# Epoch: 2955 	Training Loss: 0.276969 	Validation Loss: 0.280218
# Epoch-2956 lr: 1e-05
# Epoch: 2956 	Training Loss: 0.277463 	Validation Loss: 0.279669
# Epoch-2957 lr: 1e-05
# Epoch: 2957 	Training Loss: 0.277896 	Validation Loss: 0.285180
# Epoch-2958 lr: 1e-05
# Epoch: 2958 	Training Loss: 0.277177 	Validation Loss: 0.283172
# Epoch-2959 lr: 1e-05
# Epoch: 2959 	Training Loss: 0.275348 	Validation Loss: 0.282665
# Epoch-2960 lr: 1e-05
# Epoch: 2960 	Training Loss: 0.274735 	Validation Loss: 0.278008
# Epoch-2961 lr: 1e-05
# Epoch: 2961 	Training Loss: 0.276426 	Validation Loss: 0.279596
# Epoch-2962 lr: 1e-05
# Epoch: 2962 	Training Loss: 0.277855 	Validation Loss: 0.283646
# Epoch-2963 lr: 1e-05
# Epoch: 2963 	Training Loss: 0.275668 	Validation Loss: 0.281897
# Epoch-2964 lr: 1e-05
# Epoch: 2964 	Training Loss: 0.276721 	Validation Loss: 0.281232
# Epoch-2965 lr: 1e-05
# Epoch: 2965 	Training Loss: 0.275039 	Validation Loss: 0.279573
# Epoch-2966 lr: 1e-05
# Epoch: 2966 	Training Loss: 0.275698 	Validation Loss: 0.278465
# Epoch-2967 lr: 1e-05
# Epoch: 2967 	Training Loss: 0.277423 	Validation Loss: 0.278088
# Epoch-2968 lr: 1e-05
# Epoch: 2968 	Training Loss: 0.278069 	Validation Loss: 0.281743
# Epoch-2969 lr: 1e-05
# Epoch: 2969 	Training Loss: 0.276829 	Validation Loss: 0.281244
# Epoch-2970 lr: 1e-05
# Epoch: 2970 	Training Loss: 0.276431 	Validation Loss: 0.280108
# Epoch-2971 lr: 1e-05
# Epoch: 2971 	Training Loss: 0.276066 	Validation Loss: 0.276554
# Epoch-2972 lr: 1e-05
# Epoch: 2972 	Training Loss: 0.277763 	Validation Loss: 0.282334
# Epoch-2973 lr: 1e-05
# Epoch: 2973 	Training Loss: 0.274994 	Validation Loss: 0.281136
# Epoch-2974 lr: 1e-05
# Epoch: 2974 	Training Loss: 0.276636 	Validation Loss: 0.283324
# Epoch-2975 lr: 1e-05
# Epoch: 2975 	Training Loss: 0.275486 	Validation Loss: 0.279953
# Epoch-2976 lr: 1e-05
# Epoch: 2976 	Training Loss: 0.278225 	Validation Loss: 0.279631
# Epoch-2977 lr: 1e-05
# Epoch: 2977 	Training Loss: 0.277424 	Validation Loss: 0.278985
# Epoch-2978 lr: 1e-05
# Epoch: 2978 	Training Loss: 0.275500 	Validation Loss: 0.282264
# Epoch-2979 lr: 1e-05
# Epoch: 2979 	Training Loss: 0.275700 	Validation Loss: 0.286007
# Epoch-2980 lr: 1e-05
# Epoch: 2980 	Training Loss: 0.276797 	Validation Loss: 0.283187
# Epoch-2981 lr: 1e-05
# Epoch: 2981 	Training Loss: 0.275855 	Validation Loss: 0.279557
# Epoch-2982 lr: 1e-05
# Epoch: 2982 	Training Loss: 0.276408 	Validation Loss: 0.282958
# Epoch-2983 lr: 1e-05
# Epoch: 2983 	Training Loss: 0.277476 	Validation Loss: 0.277620
# Epoch-2984 lr: 1e-05
# Epoch: 2984 	Training Loss: 0.276054 	Validation Loss: 0.279844
# Epoch-2985 lr: 1e-05
# Epoch: 2985 	Training Loss: 0.277659 	Validation Loss: 0.286452
# Epoch-2986 lr: 1e-05
# Epoch: 2986 	Training Loss: 0.276419 	Validation Loss: 0.282897
# Epoch-2987 lr: 1e-05
# Epoch: 2987 	Training Loss: 0.276008 	Validation Loss: 0.282805
# Epoch-2988 lr: 1e-05
# Epoch: 2988 	Training Loss: 0.276625 	Validation Loss: 0.287419
# Epoch-2989 lr: 1e-05
# Epoch: 2989 	Training Loss: 0.278085 	Validation Loss: 0.280973
# Epoch-2990 lr: 1e-05
# Epoch: 2990 	Training Loss: 0.275118 	Validation Loss: 0.276643
# Epoch-2991 lr: 1e-05
# Epoch: 2991 	Training Loss: 0.276304 	Validation Loss: 0.283116
# Epoch-2992 lr: 1e-05
# Epoch: 2992 	Training Loss: 0.277245 	Validation Loss: 0.276586
# Epoch-2993 lr: 1e-05
# Epoch: 2993 	Training Loss: 0.274527 	Validation Loss: 0.285121
# Epoch-2994 lr: 1e-05
# Epoch: 2994 	Training Loss: 0.276523 	Validation Loss: 0.278207
# Epoch-2995 lr: 1e-05
# Epoch: 2995 	Training Loss: 0.276032 	Validation Loss: 0.277471
# Epoch-2996 lr: 1e-05
# Epoch: 2996 	Training Loss: 0.276788 	Validation Loss: 0.282056
# Epoch-2997 lr: 1e-05
# Epoch: 2997 	Training Loss: 0.275458 	Validation Loss: 0.278459
# Epoch-2998 lr: 1e-05
# Epoch: 2998 	Training Loss: 0.276074 	Validation Loss: 0.280058
# Epoch-2999 lr: 1e-05
# Epoch: 2999 	Training Loss: 0.276766 	Validation Loss: 0.282012
# Epoch-3000 lr: 1e-05
# Epoch: 3000 	Training Loss: 0.276342 	Validation Loss: 0.281592
# Epoch-3001 lr: 1e-05
# Epoch: 3001 	Training Loss: 0.274475 	Validation Loss: 0.280843
# Epoch-3002 lr: 1e-05
# Epoch: 3002 	Training Loss: 0.274784 	Validation Loss: 0.274968
# Epoch-3003 lr: 1e-05
# Epoch: 3003 	Training Loss: 0.275853 	Validation Loss: 0.279249
# Epoch-3004 lr: 1e-05
# Epoch: 3004 	Training Loss: 0.277431 	Validation Loss: 0.279001
# Epoch-3005 lr: 1e-05
# Epoch: 3005 	Training Loss: 0.275079 	Validation Loss: 0.278809
# Epoch-3006 lr: 1e-05
# Epoch: 3006 	Training Loss: 0.272887 	Validation Loss: 0.283730
# Epoch-3007 lr: 1e-05
# Epoch: 3007 	Training Loss: 0.275940 	Validation Loss: 0.279245
# Epoch-3008 lr: 1e-05
# Epoch: 3008 	Training Loss: 0.276710 	Validation Loss: 0.278986
# Epoch-3009 lr: 1e-05
# Epoch: 3009 	Training Loss: 0.276737 	Validation Loss: 0.282375
# Epoch-3010 lr: 1e-05
# Epoch: 3010 	Training Loss: 0.276616 	Validation Loss: 0.280947
# Epoch-3011 lr: 1e-05
# Epoch: 3011 	Training Loss: 0.275214 	Validation Loss: 0.283917
# Epoch-3012 lr: 1e-05
# Epoch: 3012 	Training Loss: 0.276755 	Validation Loss: 0.277964
# Epoch-3013 lr: 1e-05
# Epoch: 3013 	Training Loss: 0.274615 	Validation Loss: 0.282854
# Epoch-3014 lr: 1e-05
# Epoch: 3014 	Training Loss: 0.275461 	Validation Loss: 0.276554
# Epoch-3015 lr: 1e-05
# Epoch: 3015 	Training Loss: 0.275461 	Validation Loss: 0.276581
# Epoch-3016 lr: 1e-05
# Epoch: 3016 	Training Loss: 0.277716 	Validation Loss: 0.282356
# Epoch-3017 lr: 1e-05
# Epoch: 3017 	Training Loss: 0.278717 	Validation Loss: 0.287568
# Epoch-3018 lr: 1e-05
# Epoch: 3018 	Training Loss: 0.276879 	Validation Loss: 0.279196
# Epoch-3019 lr: 1e-05
# Epoch: 3019 	Training Loss: 0.277786 	Validation Loss: 0.281389
# Epoch-3020 lr: 1e-05
# Epoch: 3020 	Training Loss: 0.274950 	Validation Loss: 0.281735
# Epoch-3021 lr: 1e-05
# Epoch: 3021 	Training Loss: 0.277196 	Validation Loss: 0.279483
# Epoch-3022 lr: 1e-05
# Epoch: 3022 	Training Loss: 0.275449 	Validation Loss: 0.279348
# Epoch-3023 lr: 1e-05
# Epoch: 3023 	Training Loss: 0.274720 	Validation Loss: 0.277887
# Epoch-3024 lr: 1e-05
# Epoch: 3024 	Training Loss: 0.274988 	Validation Loss: 0.282301
# Epoch-3025 lr: 1e-05
# Epoch: 3025 	Training Loss: 0.275124 	Validation Loss: 0.275899
# Epoch-3026 lr: 1e-05
# Epoch: 3026 	Training Loss: 0.277826 	Validation Loss: 0.279569
# Epoch-3027 lr: 1e-05
# Epoch: 3027 	Training Loss: 0.276028 	Validation Loss: 0.280753
# Epoch-3028 lr: 1e-05
# Epoch: 3028 	Training Loss: 0.274566 	Validation Loss: 0.281968
# Epoch-3029 lr: 1e-05
# Epoch: 3029 	Training Loss: 0.274860 	Validation Loss: 0.280251
# Epoch-3030 lr: 1e-05
# Epoch: 3030 	Training Loss: 0.275699 	Validation Loss: 0.278303
# Epoch-3031 lr: 1e-05
# Epoch: 3031 	Training Loss: 0.274155 	Validation Loss: 0.278777
# Epoch-3032 lr: 1e-05
# Epoch: 3032 	Training Loss: 0.274686 	Validation Loss: 0.283980
# Epoch-3033 lr: 1e-05
# Epoch: 3033 	Training Loss: 0.275618 	Validation Loss: 0.277680
# Epoch-3034 lr: 1e-05
# Epoch: 3034 	Training Loss: 0.278435 	Validation Loss: 0.281413
# Epoch-3035 lr: 1e-05
# Epoch: 3035 	Training Loss: 0.273660 	Validation Loss: 0.285843
# Epoch-3036 lr: 1e-05
# Epoch: 3036 	Training Loss: 0.275204 	Validation Loss: 0.279047
# Epoch-3037 lr: 1e-05
# Epoch: 3037 	Training Loss: 0.274332 	Validation Loss: 0.274553
# Epoch-3038 lr: 1e-05
# Epoch: 3038 	Training Loss: 0.275567 	Validation Loss: 0.278048
# Epoch-3039 lr: 1e-05
# Epoch: 3039 	Training Loss: 0.275581 	Validation Loss: 0.280396
# Epoch-3040 lr: 1e-05
# Epoch: 3040 	Training Loss: 0.275898 	Validation Loss: 0.280484
# Epoch-3041 lr: 1e-05
# Epoch: 3041 	Training Loss: 0.274322 	Validation Loss: 0.276563
# Epoch-3042 lr: 1e-05
# Epoch: 3042 	Training Loss: 0.274741 	Validation Loss: 0.281878
# Epoch-3043 lr: 1e-05
# Epoch: 3043 	Training Loss: 0.274462 	Validation Loss: 0.279090
# Epoch-3044 lr: 1e-05
# Epoch: 3044 	Training Loss: 0.274972 	Validation Loss: 0.281833
# Epoch-3045 lr: 1e-05
# Epoch: 3045 	Training Loss: 0.274272 	Validation Loss: 0.282767
# Epoch-3046 lr: 1e-05
# Epoch: 3046 	Training Loss: 0.271605 	Validation Loss: 0.279242
# Epoch-3047 lr: 1e-05
# Epoch: 3047 	Training Loss: 0.273800 	Validation Loss: 0.284307
# Epoch-3048 lr: 1e-05
# Epoch: 3048 	Training Loss: 0.275239 	Validation Loss: 0.280514
# Epoch-3049 lr: 1e-05
# Epoch: 3049 	Training Loss: 0.275809 	Validation Loss: 0.279887
# Epoch-3050 lr: 1e-05
# Epoch: 3050 	Training Loss: 0.275745 	Validation Loss: 0.281634
# Epoch-3051 lr: 1e-05
# Epoch: 3051 	Training Loss: 0.278238 	Validation Loss: 0.279278
# Epoch-3052 lr: 1e-05
# Epoch: 3052 	Training Loss: 0.275176 	Validation Loss: 0.279742
# Epoch-3053 lr: 1e-05
# Epoch: 3053 	Training Loss: 0.273650 	Validation Loss: 0.279880
# Epoch-3054 lr: 1e-05
# Epoch: 3054 	Training Loss: 0.273663 	Validation Loss: 0.278468
# Epoch-3055 lr: 1e-05
# Epoch: 3055 	Training Loss: 0.275085 	Validation Loss: 0.282536
# Epoch-3056 lr: 1e-05
# Epoch: 3056 	Training Loss: 0.274009 	Validation Loss: 0.282091
# Epoch-3057 lr: 1e-05
# Epoch: 3057 	Training Loss: 0.277255 	Validation Loss: 0.280325
# Epoch-3058 lr: 1e-05
# Epoch: 3058 	Training Loss: 0.275309 	Validation Loss: 0.282446
# Epoch-3059 lr: 1e-05
# Epoch: 3059 	Training Loss: 0.273879 	Validation Loss: 0.278806
# Epoch-3060 lr: 1e-05
# Epoch: 3060 	Training Loss: 0.274532 	Validation Loss: 0.279057
# Epoch-3061 lr: 1e-05
# Epoch: 3061 	Training Loss: 0.273124 	Validation Loss: 0.280479
# Epoch-3062 lr: 1e-05
# ...
# Epoch-4813 lr: 1e-05
# Epoch: 4813 	Training Loss: 0.240044 	Validation Loss: 0.267362
# Epoch-4814 lr: 1e-05
# Epoch: 4814 	Training Loss: 0.241814 	Validation Loss: 0.267210
# Epoch-4815 lr: 1e-05
# Epoch: 4815 	Training Loss: 0.240538 	Validation Loss: 0.263173
# Epoch-4816 lr: 1e-05
# Epoch: 4816 	Training Loss: 0.239346 	Validation Loss: 0.266846
# Epoch-4817 lr: 1e-05
# Epoch: 4817 	Training Loss: 0.238400 	Validation Loss: 0.262263
# Epoch-4818 lr: 1e-05
# Epoch: 4818 	Training Loss: 0.238321 	Validation Loss: 0.263000
# Epoch-4819 lr: 1e-05
# Epoch: 4819 	Training Loss: 0.239264 	Validation Loss: 0.270362
# Epoch-4820 lr: 1e-05
# Epoch: 4820 	Training Loss: 0.240393 	Validation Loss: 0.262773
# Epoch-4821 lr: 1e-05
# Epoch: 4821 	Training Loss: 0.238200 	Validation Loss: 0.264959
# Epoch-4822 lr: 1e-05
# Epoch: 4822 	Training Loss: 0.239918 	Validation Loss: 0.263294
# Epoch-4823 lr: 1e-05
# Epoch: 4823 	Training Loss: 0.239252 	Validation Loss: 0.262504
# Epoch-4824 lr: 1e-05
# Epoch: 4824 	Training Loss: 0.241341 	Validation Loss: 0.264007
# Epoch-4825 lr: 1e-05
# Epoch: 4825 	Training Loss: 0.239738 	Validation Loss: 0.261578
# Epoch-4826 lr: 1e-05
# Epoch: 4826 	Training Loss: 0.237560 	Validation Loss: 0.267231
# Epoch-4827 lr: 1e-05
# Epoch: 4827 	Training Loss: 0.238646 	Validation Loss: 0.267321
# Epoch-4828 lr: 1e-05
# Epoch: 4828 	Training Loss: 0.239935 	Validation Loss: 0.262282
# Epoch-4829 lr: 1e-05
# Epoch: 4829 	Training Loss: 0.240625 	Validation Loss: 0.262766
# Epoch-4830 lr: 1e-05
# Epoch: 4830 	Training Loss: 0.238615 	Validation Loss: 0.265935
# Epoch-4831 lr: 1e-05
# Epoch: 4831 	Training Loss: 0.239694 	Validation Loss: 0.264951
# Epoch-4832 lr: 1e-05
# Epoch: 4832 	Training Loss: 0.237911 	Validation Loss: 0.267486
# Epoch-4833 lr: 1e-05
# Epoch: 4833 	Training Loss: 0.238886 	Validation Loss: 0.268225
# Epoch-4834 lr: 1e-05
# Epoch: 4834 	Training Loss: 0.239283 	Validation Loss: 0.268597
# Epoch-4835 lr: 1e-05
# Epoch: 4835 	Training Loss: 0.239353 	Validation Loss: 0.268406
# Epoch-4836 lr: 1e-05
# Epoch: 4836 	Training Loss: 0.239001 	Validation Loss: 0.262552
# Epoch-4837 lr: 1e-05
# Epoch: 4837 	Training Loss: 0.239113 	Validation Loss: 0.264685
# Epoch-4838 lr: 1e-05
# Epoch: 4838 	Training Loss: 0.241175 	Validation Loss: 0.272148
# Epoch-4839 lr: 1e-05
# Epoch: 4839 	Training Loss: 0.241388 	Validation Loss: 0.263619
# Epoch-4840 lr: 1e-05
# Epoch: 4840 	Training Loss: 0.240687 	Validation Loss: 0.262229
# Epoch-4841 lr: 1e-05
# Epoch: 4841 	Training Loss: 0.238769 	Validation Loss: 0.260400
# Epoch-4842 lr: 1e-05
# Epoch: 4842 	Training Loss: 0.238779 	Validation Loss: 0.263407
# Epoch-4843 lr: 1e-05
# Epoch: 4843 	Training Loss: 0.238150 	Validation Loss: 0.265830
# Epoch-4844 lr: 1e-05
# Epoch: 4844 	Training Loss: 0.239957 	Validation Loss: 0.262880
# Epoch-4845 lr: 1e-05
# Epoch: 4845 	Training Loss: 0.240304 	Validation Loss: 0.265587
# Epoch-4846 lr: 1e-05
# Epoch: 4846 	Training Loss: 0.238240 	Validation Loss: 0.267237
# Epoch-4847 lr: 1e-05
# Epoch: 4847 	Training Loss: 0.240953 	Validation Loss: 0.264989
# Epoch-4848 lr: 1e-05
# Epoch: 4848 	Training Loss: 0.238913 	Validation Loss: 0.260937
# Epoch-4849 lr: 1e-05
# Epoch: 4849 	Training Loss: 0.241267 	Validation Loss: 0.265686
# Epoch-4850 lr: 1e-05
# Epoch: 4850 	Training Loss: 0.240960 	Validation Loss: 0.264154
# Epoch-4851 lr: 1e-05
# Epoch: 4851 	Training Loss: 0.239724 	Validation Loss: 0.259879
# Epoch-4852 lr: 1e-05
# Epoch: 4852 	Training Loss: 0.238374 	Validation Loss: 0.267356
# Epoch-4853 lr: 1e-05
# Epoch: 4853 	Training Loss: 0.239226 	Validation Loss: 0.261909
# Epoch-4854 lr: 1e-05
# Epoch: 4854 	Training Loss: 0.238435 	Validation Loss: 0.265423
# Epoch-4855 lr: 1e-05
# Epoch: 4855 	Training Loss: 0.238501 	Validation Loss: 0.265951
# Epoch-4856 lr: 1e-05
# Epoch: 4856 	Training Loss: 0.239152 	Validation Loss: 0.258380
# Epoch-4857 lr: 1e-05
# Epoch: 4857 	Training Loss: 0.238336 	Validation Loss: 0.263079
# Epoch-4858 lr: 1e-05
# Epoch: 4858 	Training Loss: 0.239824 	Validation Loss: 0.264943
# Epoch-4859 lr: 1e-05
# Epoch: 4859 	Training Loss: 0.240104 	Validation Loss: 0.263446
# Epoch-4860 lr: 1e-05
# Epoch: 4860 	Training Loss: 0.237797 	Validation Loss: 0.259264
# Epoch-4861 lr: 1e-05
# Epoch: 4861 	Training Loss: 0.238408 	Validation Loss: 0.266099
# Epoch-4862 lr: 1e-05
# Epoch: 4862 	Training Loss: 0.239132 	Validation Loss: 0.269576
# Epoch-4863 lr: 1e-05
# Epoch: 4863 	Training Loss: 0.237956 	Validation Loss: 0.263937
# Epoch-4864 lr: 1e-05
# Epoch: 4864 	Training Loss: 0.238467 	Validation Loss: 0.262406
# Epoch-4865 lr: 1e-05
# Epoch: 4865 	Training Loss: 0.239195 	Validation Loss: 0.262728
# Epoch-4866 lr: 1e-05
# Epoch: 4866 	Training Loss: 0.239047 	Validation Loss: 0.270229
# Epoch-4867 lr: 1e-05
# Epoch: 4867 	Training Loss: 0.239577 	Validation Loss: 0.266948
# Epoch-4868 lr: 1e-05
# Epoch: 4868 	Training Loss: 0.238926 	Validation Loss: 0.262449
# Epoch-4869 lr: 1e-05
# Epoch: 4869 	Training Loss: 0.237324 	Validation Loss: 0.262496
# Epoch-4870 lr: 1e-05
# Epoch: 4870 	Training Loss: 0.239712 	Validation Loss: 0.264449
# Epoch-4871 lr: 1e-05
# Epoch: 4871 	Training Loss: 0.236954 	Validation Loss: 0.259405
# Epoch-4872 lr: 1e-05
# Epoch: 4872 	Training Loss: 0.238649 	Validation Loss: 0.263099
# Epoch-4873 lr: 1e-05
# Epoch: 4873 	Training Loss: 0.237627 	Validation Loss: 0.262668
# Epoch-4874 lr: 1e-05
# Epoch: 4874 	Training Loss: 0.238606 	Validation Loss: 0.265344
# Epoch-4875 lr: 1e-05
# Epoch: 4875 	Training Loss: 0.239546 	Validation Loss: 0.263043
# Epoch-4876 lr: 1e-05
# Epoch: 4876 	Training Loss: 0.238846 	Validation Loss: 0.262105
# Epoch-4877 lr: 1e-05
# Epoch: 4877 	Training Loss: 0.238038 	Validation Loss: 0.267688
# Epoch-4878 lr: 1e-05
# Epoch: 4878 	Training Loss: 0.238744 	Validation Loss: 0.259388
# Epoch-4879 lr: 1e-05
# Epoch: 4879 	Training Loss: 0.238917 	Validation Loss: 0.261318
# Epoch-4880 lr: 1e-05
# Epoch: 4880 	Training Loss: 0.239204 	Validation Loss: 0.262173
# Epoch-4881 lr: 1e-05
# Epoch: 4881 	Training Loss: 0.240226 	Validation Loss: 0.264219
# Epoch-4882 lr: 1e-05
# Epoch: 4882 	Training Loss: 0.238685 	Validation Loss: 0.261962
# Epoch-4883 lr: 1e-05
# Epoch: 4883 	Training Loss: 0.238398 	Validation Loss: 0.262710
# Epoch-4884 lr: 1e-05
# Epoch: 4884 	Training Loss: 0.239116 	Validation Loss: 0.263954
# Epoch-4885 lr: 1e-05
# Epoch: 4885 	Training Loss: 0.241519 	Validation Loss: 0.264880
# Epoch-4886 lr: 1e-05
# Epoch: 4886 	Training Loss: 0.238742 	Validation Loss: 0.263319
# Epoch-4887 lr: 1e-05
# Epoch: 4887 	Training Loss: 0.237689 	Validation Loss: 0.264086
# Epoch-4888 lr: 1e-05
# Epoch: 4888 	Training Loss: 0.239628 	Validation Loss: 0.262983
# Epoch-4889 lr: 1e-05
# Epoch: 4889 	Training Loss: 0.240000 	Validation Loss: 0.264180
# Epoch-4890 lr: 1e-05
# Epoch: 4890 	Training Loss: 0.236634 	Validation Loss: 0.270144
# Epoch-4891 lr: 1e-05
# Epoch: 4891 	Training Loss: 0.239162 	Validation Loss: 0.263339
# Epoch-4892 lr: 1e-05
# Epoch: 4892 	Training Loss: 0.237256 	Validation Loss: 0.267027
# Epoch-4893 lr: 1e-05
# Epoch: 4893 	Training Loss: 0.237087 	Validation Loss: 0.267584
# Epoch-4894 lr: 1e-05
# Epoch: 4894 	Training Loss: 0.240070 	Validation Loss: 0.266482
# Epoch-4895 lr: 1e-05
# Epoch: 4895 	Training Loss: 0.238584 	Validation Loss: 0.259609
# Epoch-4896 lr: 1e-05
# Epoch: 4896 	Training Loss: 0.237682 	Validation Loss: 0.263417
# Epoch-4897 lr: 1e-05
# Epoch: 4897 	Training Loss: 0.237848 	Validation Loss: 0.261960
# Epoch-4898 lr: 1e-05
# Epoch: 4898 	Training Loss: 0.239670 	Validation Loss: 0.268493
# Epoch-4899 lr: 1e-05
# Epoch: 4899 	Training Loss: 0.239560 	Validation Loss: 0.259763
# Epoch-4900 lr: 1e-05
# Epoch: 4900 	Training Loss: 0.237058 	Validation Loss: 0.265158
# Epoch-4901 lr: 1e-05
# Epoch: 4901 	Training Loss: 0.236592 	Validation Loss: 0.266168
# Epoch-4902 lr: 1e-05
# Epoch: 4902 	Training Loss: 0.238506 	Validation Loss: 0.260166
# Epoch-4903 lr: 1e-05
# Epoch: 4903 	Training Loss: 0.238219 	Validation Loss: 0.261433
# Epoch-4904 lr: 1e-05
# Epoch: 4904 	Training Loss: 0.239000 	Validation Loss: 0.259846
# Epoch-4905 lr: 1e-05
# Epoch: 4905 	Training Loss: 0.239356 	Validation Loss: 0.268935
# Epoch-4906 lr: 1e-05
# Epoch: 4906 	Training Loss: 0.238034 	Validation Loss: 0.257472
# Epoch-4907 lr: 1e-05
# Epoch: 4907 	Training Loss: 0.239471 	Validation Loss: 0.262819
# Epoch-4908 lr: 1e-05
# Epoch: 4908 	Training Loss: 0.240461 	Validation Loss: 0.258104
# Epoch-4909 lr: 1e-05
# Epoch: 4909 	Training Loss: 0.237035 	Validation Loss: 0.265141
# Epoch-4910 lr: 1e-05
# Epoch: 4910 	Training Loss: 0.237521 	Validation Loss: 0.264027
# Epoch-4911 lr: 1e-05
# Epoch: 4911 	Training Loss: 0.236119 	Validation Loss: 0.262612
# Epoch-4912 lr: 1e-05
# Epoch: 4912 	Training Loss: 0.236888 	Validation Loss: 0.263862
# Epoch-4913 lr: 1e-05
# Epoch: 4913 	Training Loss: 0.237532 	Validation Loss: 0.263993
# Epoch-4914 lr: 1e-05
# Epoch: 4914 	Training Loss: 0.236757 	Validation Loss: 0.268446
# Epoch-4915 lr: 1e-05
# Epoch: 4915 	Training Loss: 0.239438 	Validation Loss: 0.267452
# Epoch-4916 lr: 1e-05
# Epoch: 4916 	Training Loss: 0.236219 	Validation Loss: 0.257752
# Epoch-4917 lr: 1e-05
# Epoch: 4917 	Training Loss: 0.238374 	Validation Loss: 0.260248
# Epoch-4918 lr: 1e-05
# Epoch: 4918 	Training Loss: 0.238395 	Validation Loss: 0.263919
# Epoch-4919 lr: 1e-05
# Epoch: 4919 	Training Loss: 0.238423 	Validation Loss: 0.262592
# Epoch-4920 lr: 1e-05
# Epoch: 4920 	Training Loss: 0.238866 	Validation Loss: 0.269455
# Epoch-4921 lr: 1e-05
# Epoch: 4921 	Training Loss: 0.239277 	Validation Loss: 0.266711
# Epoch-4922 lr: 1e-05
# Epoch: 4922 	Training Loss: 0.238088 	Validation Loss: 0.265489
# Epoch-4923 lr: 1e-05
# Epoch: 4923 	Training Loss: 0.238721 	Validation Loss: 0.267101
# Epoch-4924 lr: 1e-05
# Epoch: 4924 	Training Loss: 0.239954 	Validation Loss: 0.260626
# Epoch-4925 lr: 1e-05
# Epoch: 4925 	Training Loss: 0.237279 	Validation Loss: 0.263490
# Epoch-4926 lr: 1e-05
# Epoch: 4926 	Training Loss: 0.237136 	Validation Loss: 0.263506
# Epoch-4927 lr: 1e-05
# Epoch: 4927 	Training Loss: 0.238047 	Validation Loss: 0.261680
# Epoch-4928 lr: 1e-05
# Epoch: 4928 	Training Loss: 0.238137 	Validation Loss: 0.262304
# Epoch-4929 lr: 1e-05
# Epoch: 4929 	Training Loss: 0.235969 	Validation Loss: 0.262333
# Epoch-4930 lr: 1e-05
# Epoch: 4930 	Training Loss: 0.237980 	Validation Loss: 0.267938
# Epoch-4931 lr: 1e-05
# Epoch: 4931 	Training Loss: 0.235569 	Validation Loss: 0.263410
# Epoch-4932 lr: 1e-05
# Epoch: 4932 	Training Loss: 0.236975 	Validation Loss: 0.263214
# Epoch-4933 lr: 1e-05
# Epoch: 4933 	Training Loss: 0.235427 	Validation Loss: 0.263642
# Epoch-4934 lr: 1e-05
# Epoch: 4934 	Training Loss: 0.238764 	Validation Loss: 0.260424
# Epoch-4935 lr: 1e-05
# Epoch: 4935 	Training Loss: 0.237673 	Validation Loss: 0.264283
# Epoch-4936 lr: 1e-05
# Epoch: 4936 	Training Loss: 0.239416 	Validation Loss: 0.262676
# Epoch-4937 lr: 1e-05
# Epoch: 4937 	Training Loss: 0.236438 	Validation Loss: 0.259648
# Epoch-4938 lr: 1e-05
# Epoch: 4938 	Training Loss: 0.235243 	Validation Loss: 0.261962
# Epoch-4939 lr: 1e-05
# Epoch: 4939 	Training Loss: 0.239952 	Validation Loss: 0.262760
# Epoch-4940 lr: 1e-05
# Epoch: 4940 	Training Loss: 0.236474 	Validation Loss: 0.261220
# Epoch-4941 lr: 1e-05
# Epoch: 4941 	Training Loss: 0.239155 	Validation Loss: 0.265614
# Epoch-4942 lr: 1e-05
# Epoch: 4942 	Training Loss: 0.237947 	Validation Loss: 0.265789
# Epoch-4943 lr: 1e-05
# Epoch: 4943 	Training Loss: 0.235135 	Validation Loss: 0.264512
# Epoch-4944 lr: 1e-05
# Epoch: 4944 	Training Loss: 0.238444 	Validation Loss: 0.269975
# Epoch-4945 lr: 1e-05
# Epoch: 4945 	Training Loss: 0.236325 	Validation Loss: 0.261765
# Epoch-4946 lr: 1e-05
# Epoch: 4946 	Training Loss: 0.238930 	Validation Loss: 0.261371
# Epoch-4947 lr: 1e-05
# Epoch: 4947 	Training Loss: 0.238150 	Validation Loss: 0.262618
# Epoch-4948 lr: 1e-05
# Epoch: 4948 	Training Loss: 0.236077 	Validation Loss: 0.264179
# Epoch-4949 lr: 1e-05
# Epoch: 4949 	Training Loss: 0.236180 	Validation Loss: 0.264517
# Epoch-4950 lr: 1e-05
# Epoch: 4950 	Training Loss: 0.239428 	Validation Loss: 0.264331
# Epoch-4951 lr: 1e-05
# Epoch: 4951 	Training Loss: 0.238531 	Validation Loss: 0.266660
# Epoch-4952 lr: 1e-05
# Epoch: 4952 	Training Loss: 0.236876 	Validation Loss: 0.264044
# Epoch-4953 lr: 1e-05
# Epoch: 4953 	Training Loss: 0.237508 	Validation Loss: 0.259249
# Epoch-4954 lr: 1e-05
# Epoch: 4954 	Training Loss: 0.238931 	Validation Loss: 0.268646
# Epoch-4955 lr: 1e-05
# Epoch: 4955 	Training Loss: 0.239703 	Validation Loss: 0.263591
# Epoch-4956 lr: 1e-05
# Epoch: 4956 	Training Loss: 0.235360 	Validation Loss: 0.264141
# Epoch-4957 lr: 1e-05
# Epoch: 4957 	Training Loss: 0.237900 	Validation Loss: 0.263514
# Epoch-4958 lr: 1e-05
# Epoch: 4958 	Training Loss: 0.238008 	Validation Loss: 0.267846
# Epoch-4959 lr: 1e-05
# Epoch: 4959 	Training Loss: 0.238063 	Validation Loss: 0.263866
# Epoch-4960 lr: 1e-05
# Epoch: 4960 	Training Loss: 0.237031 	Validation Loss: 0.264679
# Epoch-4961 lr: 1e-05
# Epoch: 4961 	Training Loss: 0.237547 	Validation Loss: 0.261300
# Epoch-4962 lr: 1e-05
# Epoch: 4962 	Training Loss: 0.237950 	Validation Loss: 0.265327
# Epoch-4963 lr: 1e-05
# Epoch: 4963 	Training Loss: 0.238334 	Validation Loss: 0.266430
# Epoch-4964 lr: 1e-05
# Epoch: 4964 	Training Loss: 0.234679 	Validation Loss: 0.265025
# Epoch-4965 lr: 1e-05
# Epoch: 4965 	Training Loss: 0.237092 	Validation Loss: 0.263942
# Epoch-4966 lr: 1e-05
# Epoch: 4966 	Training Loss: 0.236370 	Validation Loss: 0.258063
# Epoch-4967 lr: 1e-05
# Epoch: 4967 	Training Loss: 0.237804 	Validation Loss: 0.267187
# Epoch-4968 lr: 1e-05
# Epoch: 4968 	Training Loss: 0.237756 	Validation Loss: 0.267155
# Epoch-4969 lr: 1e-05
# Epoch: 4969 	Training Loss: 0.236038 	Validation Loss: 0.260095
# Epoch-4970 lr: 1e-05
# Epoch: 4970 	Training Loss: 0.237878 	Validation Loss: 0.265369
# Epoch-4971 lr: 1e-05
# Epoch: 4971 	Training Loss: 0.235846 	Validation Loss: 0.264225
# Epoch-4972 lr: 1e-05
# Epoch: 4972 	Training Loss: 0.237885 	Validation Loss: 0.259781
# Epoch-4973 lr: 1e-05
# Epoch: 4973 	Training Loss: 0.237424 	Validation Loss: 0.263473
# Epoch-4974 lr: 1e-05
# Epoch: 4974 	Training Loss: 0.237083 	Validation Loss: 0.263506
# Epoch-4975 lr: 1e-05
# Epoch: 4975 	Training Loss: 0.237412 	Validation Loss: 0.266265
# Epoch-4976 lr: 1e-05
# Epoch: 4976 	Training Loss: 0.238065 	Validation Loss: 0.270378
# Epoch-4977 lr: 1e-05
# Epoch: 4977 	Training Loss: 0.237307 	Validation Loss: 0.262968
# Epoch-4978 lr: 1e-05
# Epoch: 4978 	Training Loss: 0.236744 	Validation Loss: 0.260536
# Epoch-4979 lr: 1e-05
# Epoch: 4979 	Training Loss: 0.234674 	Validation Loss: 0.264902
# Epoch-4980 lr: 1e-05
# Epoch: 4980 	Training Loss: 0.234631 	Validation Loss: 0.262010
# Epoch-4981 lr: 1e-05
# Epoch: 4981 	Training Loss: 0.236296 	Validation Loss: 0.268728
# Epoch-4982 lr: 1e-05
# Epoch: 4982 	Training Loss: 0.235755 	Validation Loss: 0.264208
# Epoch-4983 lr: 1e-05
# Epoch: 4983 	Training Loss: 0.237139 	Validation Loss: 0.262640
# Epoch-4984 lr: 1e-05
# Epoch: 4984 	Training Loss: 0.235927 	Validation Loss: 0.258127
# Epoch-4985 lr: 1e-05
# Epoch: 4985 	Training Loss: 0.238435 	Validation Loss: 0.262654
# Epoch-4986 lr: 1e-05
# Epoch: 4986 	Training Loss: 0.235953 	Validation Loss: 0.260829
# Epoch-4987 lr: 1e-05
# Epoch: 4987 	Training Loss: 0.236063 	Validation Loss: 0.262968
# Epoch-4988 lr: 1e-05
# Epoch: 4988 	Training Loss: 0.237348 	Validation Loss: 0.260724
# Epoch-4989 lr: 1e-05
# Epoch: 4989 	Training Loss: 0.235896 	Validation Loss: 0.263785
# Epoch-4990 lr: 1e-05
# Epoch: 4990 	Training Loss: 0.235406 	Validation Loss: 0.263411
# Epoch-4991 lr: 1e-05
# Epoch: 4991 	Training Loss: 0.236234 	Validation Loss: 0.260149
# Epoch-4992 lr: 1e-05
# Epoch: 4992 	Training Loss: 0.236943 	Validation Loss: 0.262701
# Epoch-4993 lr: 1e-05
# Epoch: 4993 	Training Loss: 0.236264 	Validation Loss: 0.260941
# Epoch-4994 lr: 1e-05
# Epoch: 4994 	Training Loss: 0.235656 	Validation Loss: 0.261570
# Epoch-4995 lr: 1e-05
# Epoch: 4995 	Training Loss: 0.235408 	Validation Loss: 0.263279
# Epoch-4996 lr: 1e-05
# Epoch: 4996 	Training Loss: 0.238628 	Validation Loss: 0.261653
# Epoch-4997 lr: 1e-05
# Epoch: 4997 	Training Loss: 0.237864 	Validation Loss: 0.258853
# Epoch-4998 lr: 1e-05
# Epoch: 4998 	Training Loss: 0.237991 	Validation Loss: 0.261667
# Epoch-4999 lr: 1e-05
# Epoch: 4999 	Training Loss: 0.238893 	Validation Loss: 0.269326
# Epoch-5000 lr: 1e-05
# Epoch: 5000 	Training Loss: 0.237045 	Validation Loss: 0.269483

# %%
torch.save(model, '/content/gdrive/My Drive/scg_vae1_weights_vaihingen1.pt')

# %%
#!pip install tensorboard

# %%
#%tensorboard --logdir=runs

# %%
'''
plt.plot(np.arange(50),trainingloss,label='Training loss')
#plt.show()
#plt.plot(np.arange(50),testloss,label='Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
'''
'''
plt.plot(np.arange(100),trainingloss,label='Training loss')
#plt.show()
plt.plot(np.arange(100),testloss,label='Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
#test_loss
'''
# Out:
# "\nplt.plot(np.arange(100),trainingloss,label='Training loss')\n#plt.show()\nplt.plot(np.arange(100),testloss,label='Test loss')\nplt.xlabel('Epochs')\nplt.ylabel('Loss')\nplt.legend()\nplt.show()\n#test_loss\n"

# %%
plt.plot(train_losses)
plt.plot(valid_losses)

plt.legend(["train_loss", "valid_loss"])

# %%
import logging
def plot_bi(inpt,ori_imgs, recon_imgs, figsize = (5, 5)):
    IMG_SIZE=512
    print()
    fig, axes = plt.subplots(1, 3, figsize = figsize)
    fig.subplots_adjust(hspace=0.4, wspace = 0.4, right =0.7)
    
    axes[0].imshow(np.transpose(inpt,(1,2,0)))
    axes[0].set_xlabel('inp')
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    
    axes[1].imshow(ori_imgs)#np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]))
    axes[1].set_xlabel('mask')
    axes[1].set_xticks([])
    axes[1].set_yticks([])

    axes[2].imshow(recon_imgs)#np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]))
    axes[2].set_xlabel('mask')
    axes[2].set_xticks([])
    axes[2].set_yticks([])

   

    plt.tight_layout()
    plt.show()
def plot(ori_imgs, recon_imgs, masked_imgs,masked_imgs1, figsize = (10, 10)):
    IMG_SIZE=240
    print()
    fig, axes = plt.subplots(1, 4, figsize = figsize)
    fig.subplots_adjust(hspace=0.4, wspace = 0.4, right =0.7)
    
    axes[0].imshow(np.reshape(ori_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[0].set_xlabel('channel 0')
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    
    axes[1].imshow(np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[1].set_xlabel('channel 2')
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    
    axes[2].imshow(np.reshape(masked_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[2].set_xlabel('Channel 3')
    axes[2].set_xticks([])
    axes[2].set_yticks([])

    
    
    plt.tight_layout()
    plt.show()

def plot_testoutputs(test_input,test_pred,test_gt):
    #for each in range(200):
        
      inpti=test_input#[1]
      predti=test_pred#[1]
      gtti=test_gt#[1]
      #print('epoch no :',test_iter_epoch[each])
      
      #print('input',inpti.shape)
      #print('pred',predti.shape)
      #print('gt',gtti.shape)
      
      inpti=inpti.squeeze().cpu().detach().numpy()
      predti=predti.squeeze().cpu().detach().numpy()
      gtti=gtti.squeeze().cpu().detach().numpy()
      #predti=predti.squeeze().cpu().detach().numpy()
      print('dice_loss:',dice(predti,gtti))
      #print(predt1.shape)
      #predti=predti.numpy()
      #print(predti.shape)
      
      
      
      #thresh = threshold_otsu(predti)
      #predti[predti<=0.1] = 0
      #predti[predti>0.1] = 1
        #plot1(inpti[0],inpti[1],inpti[2],inpti[3])
      colur_maski=create_diff_mask_binary(predti, gtti)
      
      plot_bi(inpti,predti,colur_maski)
class Logger:
    def __init__(self, model_name, logger_path):
        self.logger = logging.getLogger(model_name)
        hdlr = logging.FileHandler(logger_path)
        formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
        hdlr.setFormatter(formatter)
        self.logger.addHandler(hdlr)
        self.logger.setLevel(logging.DEBUG)

    def get_logger(self):
      return self.logger

from skimage.filters import threshold_otsu
def create_mask(predicted):
    """
    Method find the difference between the 2 images and overlay colors
    predicted, label : slices , 2D tensor
    """
    predicted = predicted.cpu().data.numpy()

    
    thresh = threshold_otsu(predicted)
    predicted_binary = predicted > thresh
    
    predicted_binary = predicted > 0.5  # exception will be thrown only if input image seems to have just one color 1.0.

    # Define colors
    black = np.array([0, 0, 0], dtype=np.uint8)  # background
    white = np.array([255, 255, 255], dtype=np.uint8)  # prediction_output

    # Make RGB array, pre-filled with black(background)
    rgb_image = np.zeros((predicted_binary.shape[0], predicted_binary.shape[1], 3), dtype=np.uint8) + black

    # Overwrite with red where threshold exceeded, i.e. where mask is True
    rgb_image[predicted_binary] = white

    return rgb_image

def create_diff_mask(predicted, label):
    """
    Method find the difference between the 2 images(predicted being grescale, label being binary) and overlay colors
    predicted, label : slices , 2D tensor
    """
    label = label.cpu().data.numpy()
    predicted = predicted.cpu().data.numpy()

    
    thresh = threshold_otsu(predicted)
    predicted_binary = predicted > thresh
    
    predicted_binary = predicted > 0.5  # exception will be thrown only if input image seems to have just one color 1.0.

    

    diff1 = np.subtract(label, predicted_binary) > 0
    diff2 = np.subtract(predicted_binary, label) > 0

    # Define colors
    red = np.array([255, 0, 0], dtype=np.uint8)  # under_detected
    green = np.array([0, 255, 0], dtype=np.uint8)  # over_detected
    black = np.array([0, 0, 0], dtype=np.uint8)  # background
    white = np.array([255, 255, 255], dtype=np.uint8)  # prediction_output
    blue = np.array([0, 0, 255], dtype=np.uint8) # over_detected
    yellow = np.array([255, 255, 0], dtype=np.uint8)  # under_detected

    # Make RGB array, pre-filled with black(background)
    rgb_image = np.zeros((predicted_binary.shape[0], predicted_binary.shape[1], 3), dtype=np.uint8) + black

    # Overwrite with red where threshold exceeded, i.e. where mask is True
    rgb_image[predicted_binary] = white
    rgb_image[diff1] = red
    rgb_image[diff2] = blue

    return rgb_image

def create_diff_mask_binary(predicted, label):
    """
    Method find the difference between the 2 binary images and overlay colors
    predicted, label : slices , 2D tensor
    """
    predicted_label = label#.cpu().data.numpy()
    predicted_binary = predicted#.cpu().data.numpy()

    diff1 = np.subtract(predicted_label, predicted_binary) > 0
    diff2 = np.subtract(predicted_binary, predicted_label) > 0

    predicted_binary = predicted_binary > 0

    # Define colors
    red = np.array([255, 0, 0], dtype=np.uint8)  # under_detected
    green = np.array([0, 255, 0], dtype=np.uint8)  # over_detected
    black = np.array([0, 0, 0], dtype=np.uint8)  # background
    white = np.array([255, 255, 255], dtype=np.uint8)  # prediction_output
    blue = np.array([0, 0, 255], dtype=np.uint8) # over_detected
    yellow = np.array([255, 255, 0], dtype=np.uint8)  # under_detected

    # Make RGB array, pre-filled with black(background)
    rgb_image = np.zeros((predicted_binary.shape[0], predicted_binary.shape[1], 3), dtype=np.uint8) + black

    # Overwrite with red where threshold exceeded, i.e. where mask is True

    #predicted_binary=np.transpose(predicted_binary, (1, 0, 2))
    rgb_image[predicted_binary] = white
    rgb_image[diff1] = red
    rgb_image[diff2] = blue
    return rgb_image



def show_diff(label, predicted, diff_image):
    '''
   Method to display the differences between label, predicted and diff_image
   '''
    fig, axes = plt.subplots(ncols=3, figsize=(8, 2.5))
    ax = axes
    ax[0] = plt.subplot(1, 3, 1)
    ax[1] = plt.subplot(1, 3, 2)
    ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

    ax[0].imshow(label, cmap=plt.cm.gray)
    ax[0].set_title('GroundTruth')
    ax[0].axis('off')

    ax[1].imshow(predicted, cmap=plt.cm.gray)
    ax[1].set_title('Predicted')
    ax[0].axis('off')

    ax[2].imshow(diff_image, cmap=plt.cm.gray)
    ax[2].set_title('Difference image')
    ax[2].axis('off')

    plt.show()
def dice(im1, im2):
    """
    Computes the Dice coefficient, a measure of set similarity.
    Parameters
    ----------
    im1 : array-like, bool
        Any array of arbitrary size. If not boolean, will be converted.
    im2 : array-like, bool
        Any other array of identical size. If not boolean, will be converted.
    Returns
    -------
    dice : float
        Dice coefficient as a float on range [0,1].
        Maximum similarity = 1
        No similarity = 0
        
    Notes
    -----
    The order of inputs for `dice` is irrelevant. The result will be
    identical if `im1` and `im2` are switched.
    """
    im1 = np.asarray(im1).astype(np.bool)
    im2 = np.asarray(im2).astype(np.bool)

    if im1.shape != im2.shape:
        raise ValueError("Shape mismatch: im1 and im2 must have the same shape.")

    # Compute Dice coefficient
    intersection = np.logical_and(im1, im2)

    return 2. * intersection.sum() / (im1.sum() + im2.sum())
def plot1(ori_imgs, recon_imgs, masked_imgs,masked_imgs1, figsize = (10, 10)):
    IMG_SIZE=192
    print()
    
    fig, axes = plt.subplots(1, 4, figsize = figsize)
    fig.subplots_adjust(hspace=0.4, wspace = 0.4, right =0.7)
    
    axes[0].imshow(np.reshape(ori_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[0].set_xlabel('channel 0')
    axes[0].set_xticks([])
    axes[0].set_yticks([])
    
    axes[1].imshow(np.reshape(recon_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[1].set_xlabel('channel 2')
    axes[1].set_xticks([])
    axes[1].set_yticks([])
    
    axes[2].imshow(np.reshape(masked_imgs,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[2].set_xlabel('Channel 3')
    axes[2].set_xticks([])
    axes[2].set_yticks([])

    axes[3].imshow(np.reshape(masked_imgs1,[IMG_SIZE, IMG_SIZE]), cmap = 'gray')
    axes[3].set_xlabel('Channel 4')
    axes[3].set_xticks([])
    axes[3].set_yticks([])
    
    plt.tight_layout()
    plt.show()

# %%
#model = torch.load('/content/gdrive/My Drive/scg_vae_weights_vaihingen.pt')

def acc_metric(predb, yb):
    return (predb.argmax(dim=1) == yb.cuda()).float().mean()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" )

#my_dataset = BRATSDataset2D(root_path=folder_path_fully,binarise=True)
#my_dataloader = DataLoader(my_dataset,batch_size=1, shuffle=True)

test_dataset = BRATSDataset2D(input_path=test_x_path,gt_path=test_y_path,binarise=True)
test_loader = DataLoader(test_dataset,batch_size=1,shuffle=True)
writer = SummaryWriter()

model.cuda()

#optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
batch_size=1
trainingloss=[]
testloss=[]
iters=[]

train_input=[]
test_input=[]
train_pred=[]
test_pred=[]
train_gt=[]
test_gt=[]
train_iter_epoch=[]
test_iter_epoch=[]
test_losses=[]
loss_fn=Dice()
testloss=Dice()



    
  
with torch.no_grad():
    model.eval()
        
    test_losses=[]
    for images,labels in test_loader:
      if (torch.min(images) == 0 and torch.max(images) == 0)  :
          continue
      #images=data_transform(images)
      images=images.cuda().float()
      #images=images.permute(0,3,1,2)
      #print(images.shape)   
      outputtest,mut,logvart,cnft,zt,featt = model(images)
        
          #test_loss = dice_loss(outputs.cuda(), labels.cuda())
          
          #test_loss=testloss(outputs, labels.cuda())
          #test_losses.append(float(test_loss))
      #print(images.shape)
      #print(outputs.shape)
      #print(labels.shape)
      print('accuracy',acc_metric(outputtest,images))
      plot_testoutputs(images,outputtest,labels)
      test_input.append(images)
      test_pred.append(outputtest)
      test_gt.append(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# accuracy tensor(0., device='cuda:0')
# dice_loss: 0.8618467897396711
# accuracy tensor(0., device='cuda:0')
# dice_loss: 0.8576782208742676
# accuracy tensor(0., device='cuda:0')
# dice_loss: 0.8775223141168235
# accuracy tensor(0., device='cuda:0')
# dice_loss: 0.8623580084842304
